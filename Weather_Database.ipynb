# barrow us
# kavaratti in
# la ronge ca
# saskylakh ru
# hermanus za
# airai pw
# kerteh my
# beloha mg
# fortuna us
# kathu th
# mana gf
# sitka us
# carnarvon au
# tuktoyaktuk ca
# busselton au
# ushuaia ar
# bam ir
# whitehaven gb
# hermanus za
# campeche mx
# ojinaga mx
# victoria sc
# saint anthony ca
# gizo sb
# bilibino ru
# kampot kh
# busselton au
# hobart au
# lorengau pg
# kuusamo fi
# mbaiki cf
# tiksi ru
# vaitupu wf
# luanda ao
# punta arenas cl
# hamilton bm
# jonkoping se
# pevek ru
# taolanaro mg
# tiksi ru
# lebu cl
# atlantic city us
# albany au
# kapaa us
# tromso no
# ponta do sol cv
# bambous virieux mu
# hilo us
# montelimar fr
# punta arenas cl
# vila velha br
# mpanda tz
# tasiilaq gl
# butaritari ki
# vila franca do campo pt
# alofi nu
# busselton au
# san patricio mx
# constitucion mx
# clyde river ca
# san cristobal ec
# vardo no
# rikitea pf
# isangel vu
# rikitea pf
# drumnadrochit gb
# cidreira br
# mudyuga ru
# new norfolk au
# bredasdorp za
# nowy tomysl pl
# lompoc us
# svetlyy ru
# zile tr
# albany au
# nurota uz
# los llanos de aridane es
# yellowknife ca
# busselton au
# punta arenas cl
# port alfred za
# muli mv
# busselton au
# namibe ao
# ushuaia ar
# victoria sc
# mataura pf
# beloha mg
# dunedin nz
# kapaa us
# albany au
# belushya guba ru
# bluff nz
# rikitea pf
# saskylakh ru
# pisco pe
# vaini to
# talnakh ru
# georgetown sh
# albany au
# kodiak us
# san patricio mx
# mataura pf
# vung tau vn
# srednekolymsk ru
# cape town za
# yulara au
# esperance au
# punta arenas cl
# gizo sb
# rikitea pf
# yulara au
# klaksvik fo
# geraldton au
# albany au
# saskylakh ru
# nouadhibou mr
# misratah ly
# hobart au
# san felipe mx
# punta arenas cl
# cape town za
# mongu zm
# isangel vu
# avarua ck
# severo-kurilsk ru
# constitucion mx
# staryy nadym ru
# luanda ao
# portree gb
# hamilton bm
# jamestown sh
# punta arenas cl
# yerbogachen ru
# albany au
# manjacaze mz
# avarua ck
# iqaluit ca
# barrow us
# hilo us
# vaini to
# olafsvik is
# bluff nz
# kapaa us
# cherskiy ru
# provideniya ru
# belushya guba ru
# mys shmidta ru
# port alfred za
# kapaa us
# hualmay pe
# saskylakh ru
# grindavik is
# arraial do cabo br
# kalakamati bw
# bredasdorp za
# tubruq ly
# orsta no
# whitehorse ca
# ossora ru
# arraial do cabo br
# port blair in
# behbahan ir
# te anau nz
# vanimo pg
# gornyy ru
# dunedin nz
# cumaribo co
# avarua ck
# berlevag no
# dikson ru
# esperance au
# mataura pf
# manthani in
# fourmies fr
# albany au
# miracema do tocantins br
# bouca cf
# itarema br
# hithadhoo mv
# cape town za
# severo-kurilsk ru
# port alfred za
# temaraia ki
# darab ir
# utiroa ki
# ribeira grande pt
# lure fr
# fare pf
# khatanga ru
# marcona pe
# husavik is
# chicama pe
# muleba tz
# qaanaaq gl
# mataura pf
# rikitea pf
# kapaa us
# leshukonskoye ru
# kaitangata nz
# cidreira br
# brae gb
# maningrida au
# oni ge
# port elizabeth za
# roma au
# beloha mg
# albany au
# taywarah af
# rikitea pf
# butaritari ki
# maniitsoq gl
# grand gaube mu
# atuona pf
# ajdabiya ly
# andselv no
# kaitangata nz
# georgetown sh
# fortuna us
# saint-augustin ca
# new norfolk au
# hazorasp uz
# moroto ug
# tuktoyaktuk ca
# atuona pf
# georgetown sh
# thompson ca
# rikitea pf
# torbay ca
# bengkulu id
# aasiaat gl
# tuktoyaktuk ca
# thompson ca
# taoudenni ml
# saint-pierre re
# pochutla mx
# bayangol ru
# hermanus za
# rikitea pf
# tasiilaq gl
# seoul kr
# cockburn town tc
# rikitea pf
# ushuaia ar
# luganville vu
# ushuaia ar
# chokurdakh ru
# bluff nz
# rikitea pf
# senneterre ca
# kargopol ru
# kapaa us
# vaitupu wf
# sumbawa id
# ribeira brava cv
# upernavik gl
# ugoofaaru mv
# hermanus za
# kaitangata nz
# malumfashi ng
# rikitea pf
# bengkulu id
# ewa beach us
# kearney us
# huarmey pe
# yellowknife ca
# husavik is
# saint george bm
# deniliquin au
# punta arenas cl
# ushuaia ar
# klaksvik fo
# dalianwan cn
# saleaula ws
# marystown ca
# leh in
# punta arenas cl
# cape town za
# dauphin ca
# bluff nz
# cedral mx
# port alfred za
# powell river ca
# cayenne gf
# galesong id
# kaitangata nz
# ubinskoye ru
# busselton au
# glenwood springs us
# saint-philippe re
# jamestown sh
# lavrentiya ru
# cape town za
# bredasdorp za
# hobyo so
# teguise es
# jamestown sh
# port hedland au
# narsaq gl
# hermanus za
# namatanai pg
# mys shmidta ru
# hobart au
# mehamn no
# kathu za
# provideniya ru
# rikitea pf
# bontang id
# quipapa br
# vaini to
# grand river south east mu
# new norfolk au
# lebu cl
# kodinsk ru
# norman wells ca
# luderitz na
# kaitangata nz
# codrington ag
# albany au
# nikolskoye ru
# provideniya ru
# new norfolk au
# bethel us
# tasiilaq gl
# punta arenas cl
# makushino ru
# kaitangata nz
# kapaa us
# lavrentiya ru
# jamestown sh

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 620

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce4ebff87f37966dcddd7ce8a1d64a19

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
#Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
   
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                        })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 21 of Set 49 | vaini
# Processing Record 22 of Set 49 | nishihara
# Processing Record 23 of Set 49 | rikitea
# Processing Record 24 of Set 49 | ushuaia
# Processing Record 25 of Set 49 | hermanus
# Processing Record 26 of Set 49 | mount isa
# Processing Record 27 of Set 49 | antalaha
# Processing Record 28 of Set 49 | honiara
# Processing Record 29 of Set 49 | west wendover
# Processing Record 30 of Set 49 | yantal
# Processing Record 31 of Set 49 | punta arenas
# Processing Record 32 of Set 49 | kapaa
# Processing Record 33 of Set 49 | taksimo
# Processing Record 34 of Set 49 | mlonggo
# Processing Record 35 of Set 49 | asau
# Processing Record 36 of Set 49 | methoni
# Processing Record 37 of Set 49 | buon me thuot
# City not found. Skipping...
# Processing Record 38 of Set 49 | clyde river
# Processing Record 39 of Set 49 | cape town
# Processing Record 40 of Set 49 | goderich
# Processing Record 41 of Set 49 | fare
# Processing Record 42 of Set 49 | busselton
# Processing Record 43 of Set 49 | leningradskiy
# Processing Record 44 of Set 49 | bluff
# Processing Record 45 of Set 49 | mataura
# Processing Record 46 of Set 49 | puerto ayora
# Processing Record 47 of Set 49 | albany
# Processing Record 48 of Set 49 | bethel
# Processing Record 49 of Set 49 | brooks
# Processing Record 50 of Set 49 | teya
# Processing Record 51 of Set 49 | yanchukan
# City not found. Skipping...
# Processing Record 52 of Set 49 | araucaria
# Processing Record 53 of Set 49 | dubrovka
# Processing Record 54 of Set 49 | enumclaw
# Processing Record 55 of Set 49 | hobart
# Processing Record 56 of Set 49 | oriximina
# Processing Record 57 of Set 49 | carnarvon
# Processing Record 58 of Set 49 | radchenko
# Processing Record 59 of Set 49 | lenauheim
# Processing Record 60 of Set 49 | alofi
# Processing Record 61 of Set 49 | victoria
# Processing Record 62 of Set 49 | paytug
# City not found. Skipping...
# Processing Record 63 of Set 49 | henties bay
# Processing Record 64 of Set 49 | jamestown
# Processing Record 65 of Set 49 | jetalsar
# Processing Record 66 of Set 49 | sokolo
# Processing Record 67 of Set 49 | san patricio
# Processing Record 68 of Set 49 | east london
# Processing Record 69 of Set 49 | shush
# Processing Record 70 of Set 49 | maldonado
# Processing Record 1 of Set 50 | bambous virieux
# Processing Record 2 of Set 50 | imeni poliny osipenko
# Processing Record 3 of Set 50 | cozumel
# Processing Record 4 of Set 50 | arraial do cabo
# Processing Record 5 of Set 50 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 50 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 50 | lebu
# Processing Record 8 of Set 50 | flin flon
# Processing Record 9 of Set 50 | svetlaya
# Processing Record 10 of Set 50 | paragould
# Processing Record 11 of Set 50 | nanortalik
# Processing Record 12 of Set 50 | nhulunbuy
# Processing Record 13 of Set 50 | parga
# Processing Record 14 of Set 50 | komsomolskiy
# Processing Record 15 of Set 50 | fairfield
# Processing Record 16 of Set 50 | lorengau
# Processing Record 17 of Set 50 | hilo
# Processing Record 18 of Set 50 | mar del plata
# Processing Record 19 of Set 50 | neftcala
# Processing Record 20 of Set 50 | dikson
# Processing Record 21 of Set 50 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 50 | yellowknife
# Processing Record 23 of Set 50 | mount gambier
# Processing Record 24 of Set 50 | port hedland
# Processing Record 25 of Set 50 | severo-kurilsk
# Processing Record 26 of Set 50 | mogadishu
# Processing Record 27 of Set 50 | dolbeau
# City not found. Skipping...
# Processing Record 28 of Set 50 | tuktoyaktuk
# Processing Record 29 of Set 50 | belmonte
# Processing Record 30 of Set 50 | lavrentiya
# Processing Record 31 of Set 50 | hun
# Processing Record 32 of Set 50 | quatre cocos
# Processing Record 33 of Set 50 | ribeira grande
# Processing Record 34 of Set 50 | nara
# Processing Record 35 of Set 50 | sao filipe
# Processing Record 36 of Set 50 | simpang
# Processing Record 37 of Set 50 | barrow
# Processing Record 38 of Set 50 | husavik
# Processing Record 39 of Set 50 | georgetown
# Processing Record 40 of Set 50 | atuona
# Processing Record 41 of Set 50 | eshowe
# Processing Record 42 of Set 50 | saskylakh
# Processing Record 43 of Set 50 | khonuu
# City not found. Skipping...
# Processing Record 44 of Set 50 | avarua
# Processing Record 45 of Set 50 | tabas
# Processing Record 46 of Set 50 | corinto
# Processing Record 47 of Set 50 | nikolskoye
# Processing Record 48 of Set 50 | khatanga
# Processing Record 49 of Set 50 | vao
# Processing Record 50 of Set 50 | marawi
# Processing Record 1 of Set 51 | port elizabeth
# Processing Record 2 of Set 51 | nehe
# Processing Record 3 of Set 51 | baft
# Processing Record 4 of Set 51 | narsaq
# Processing Record 5 of Set 51 | patti
# Processing Record 6 of Set 51 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 51 | ust-kuyga
# Processing Record 8 of Set 51 | haines junction
# Processing Record 9 of Set 51 | perdoes
# Processing Record 10 of Set 51 | ponta do sol
# Processing Record 11 of Set 51 | okha
# Processing Record 12 of Set 51 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 51 | muros
# Processing Record 14 of Set 51 | qostanay
# Processing Record 15 of Set 51 | isangel
# Processing Record 16 of Set 51 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 51 | tucuman
# Processing Record 18 of Set 51 | ambilobe
# Processing Record 19 of Set 51 | bredasdorp
# Processing Record 20 of Set 51 | huangzhou
# Processing Record 21 of Set 51 | aklavik
# Processing Record 22 of Set 51 | berlevag
# Processing Record 23 of Set 51 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 51 | makung
# City not found. Skipping...
# Processing Record 25 of Set 51 | athabasca
# Processing Record 26 of Set 51 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 51 | port alfred
# Processing Record 28 of Set 51 | terrak
# Processing Record 29 of Set 51 | olawa
# Processing Record 30 of Set 51 | yeppoon
# Processing Record 31 of Set 51 | monster
# Processing Record 32 of Set 51 | ossipee
# Processing Record 33 of Set 51 | kodiak
# Processing Record 34 of Set 51 | bonavista
# Processing Record 35 of Set 51 | salamiyah
# Processing Record 36 of Set 51 | ayan
# Processing Record 37 of Set 51 | beringovskiy
# Processing Record 38 of Set 51 | starokozache
# Processing Record 39 of Set 51 | nelson bay
# Processing Record 40 of Set 51 | inhambane
# Processing Record 41 of Set 51 | new norfolk
# Processing Record 42 of Set 51 | nome
# Processing Record 43 of Set 51 | hofn
# Processing Record 44 of Set 51 | bengkulu
# Processing Record 45 of Set 51 | mahebourg
# Processing Record 46 of Set 51 | wachtersbach
# Processing Record 47 of Set 51 | grand gaube
# Processing Record 48 of Set 51 | chokurdakh
# Processing Record 49 of Set 51 | pisco
# Processing Record 50 of Set 51 | akyab
# Processing Record 1 of Set 52 | bonnyville
# Processing Record 2 of Set 52 | meyungs
# City not found. Skipping...
# Processing Record 3 of Set 52 | bathsheba
# Processing Record 4 of Set 52 | kloulklubed
# Processing Record 5 of Set 52 | eyl
# Processing Record 6 of Set 52 | bakchar
# Processing Record 7 of Set 52 | sao jose da coroa grande
# Processing Record 8 of Set 52 | tasiilaq
# Processing Record 9 of Set 52 | cabo san lucas
# Processing Record 10 of Set 52 | valparaiso
# Processing Record 11 of Set 52 | unguia
# Processing Record 12 of Set 52 | gambissara
# Processing Record 13 of Set 52 | xingyi
# Processing Record 14 of Set 52 | priladozhskiy
# Processing Record 15 of Set 52 | cidreira
# Processing Record 16 of Set 52 | vardo
# Processing Record 17 of Set 52 | ketchikan
| marcona
# City not found. Skipping...
# Processing Record 36 of Set 53 | hokitika
# Processing Record 37 of Set 53 | petrolina
# Processing Record 38 of Set 53 | shimorskoye
# Processing Record 39 of Set 53 | serov
# Processing Record 40 of Set 53 | eastbourne
# Processing Record 41 of Set 53 | awjilah
# Processing Record 42 of Set 53 | milkovo
# Processing Record 43 of Set 53 | broome
# Processing Record 44 of Set 53 | china
# Processing Record 45 of Set 53 | sambava
# Processing Record 46 of Set 53 | ancud
# Processing Record 47 of Set 53 | anadyr
# Processing Record 48 of Set 53 | fortuna
# Processing Record 49 of Set 53 | mandalgovi
# Processing Record 50 of Set 53 | esmeralda
# Processing Record 1 of Set 54 | hammerfest
# Processing Record 2 of Set 54 | elesbao veloso
# Processing Record 3 of Set 54 | sistranda
# Processing Record 4 of Set 54 | glendive
# Processing Record 5 of Set 54 | rawson
# Processing Record 6 of Set 54 | kavieng
# Processing Record 7 of Set 54 | brownsville
# Processing Record 8 of Set 54 | casa nova
# Processing Record 9 of Set 54 | yulara
# Processing Record 10 of Set 54 | marzuq
# Processing Record 11 of Set 54 | cabatuan
# Processing Record 12 of Set 54 | klyuchi
# Processing Record 13 of Set 54 | guerrero negro
# Processing Record 14 of Set 54 | rungata
# City not found. Skipping...
# Processing Record 15 of Set 54 | desbiens
# Processing Record 16 of Set 54 | westport
# Processing Record 17 of Set 54 | kousseri
# Processing Record 18 of Set 54 | tyup
# Processing Record 19 of Set 54 | tiksi
# Processing Record 20 of Set 54 | eydhafushi
# Processing Record 21 of Set 54 | emerald
# Processing Record 22 of Set 54 | mana
# Processing Record 23 of Set 54 | haibowan
# City not found. Skipping...
# Processing Record 24 of Set 54 | vytegra
# Processing Record 25 of Set 54 | airai
# Processing Record 26 of Set 54 | tongren
# Processing Record 27 of Set 54 | sinnamary
# Processing Record 28 of Set 54 | tuatapere
# Processing Record 29 of Set 54 | sabla
# Processing Record 30 of Set 54 | hasaki
# Processing Record 31 of Set 54 | zapolyarnyy
# Processing Record 32 of Set 54 | baykit
# Processing Record 33 of Set 54 | te anau
# Processing Record 34 of Set 54 | esperance
# Processing Record 35 of Set 54 | erzin
# Processing Record 36 of Set 54 | yendi
# Processing Record 37 of Set 54 | cadillac
# Processing Record 38 of Set 54 | zhangye
# Processing Record 39 of Set 54 | fallon
# Processing Record 40 of Set 54 | gushi
# Processing Record 41 of Set 54 | ludvika
# Processing Record 42 of Set 54 | saly
# Processing Record 43 of Set 54 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 54 | cao bang
# Processing Record 45 of Set 54 | sungaipenuh
# Processing Record 46 of Set 54 | coruripe
# Processing Record 47 of Set 54 | totness
# Processing Record 48 of Set 54 | noumea
# Processing Record 49 of Set 54 | saldanha
# Processing Record 50 of Set 54 | lima
# Processing Record 1 of Set 55 | namibe
# Processing Record 2 of Set 55 | sillod
# Processing Record 3 of Set 55 | tazovskiy
# Processing Record 4 of Set 55 | ujjain
# Processing Record 5 of Set 55 | kruisfontein
# Processing Record 6 of Set 55 | iqaluit
# Processing Record 7 of Set 55 | vallenar
# Processing Record 8 of Set 55 | cotonou
# Processing Record 9 of Set 55 | marrakesh
# Processing Record 10 of Set 55 | high level
# Processing Record 11 of Set 55 | mehendiganj
# Processing Record 12 of Set 55 | buchanan
| bolshoye sorokino
# City not found. Skipping...
# Processing Record 44 of Set 56 | pavino
# Processing Record 45 of Set 56 | farah
# Processing Record 46 of Set 56 | uzhur
# Processing Record 47 of Set 56 | tupik
# Processing Record 48 of Set 56 | kihurio
# Processing Record 49 of Set 56 | newport
# Processing Record 50 of Set 56 | coolum beach
# Processing Record 1 of Set 57 | burgeo
# Processing Record 2 of Set 57 | sao joao da barra
# Processing Record 3 of Set 57 | miquelon
# Processing Record 4 of Set 57 | port lincoln
# Processing Record 5 of Set 57 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 57 | krasnoselkup
# Processing Record 7 of Set 57 | tindivanam
# Processing Record 8 of Set 57 | ndele
# Processing Record 9 of Set 57 | paradwip
# City not found. Skipping...
# Processing Record 10 of Set 57 | cesky dub
# Processing Record 11 of Set 57 | ngaoundere
# Processing Record 12 of Set 57 | la ronge
# Processing Record 13 of Set 57 | chililabombwe
# Processing Record 14 of Set 57 | adeje
# Processing Record 15 of Set 57 | wolgast
# Processing Record 16 of Set 57 | mirpur khas
# Processing Record 17 of Set 57 | tigil
# Processing Record 18 of Set 57 | rio gallegos
# Processing Record 19 of Set 57 | kenai
# Processing Record 20 of Set 57 | alekseyevsk
# Processing Record 21 of Set 57 | portland
# Processing Record 22 of Set 57 | kununurra
# Processing Record 23 of Set 57 | camapua
# Processing Record 24 of Set 57 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 57 | beauceville
# Processing Record 26 of Set 57 | ola
# Processing Record 27 of Set 57 | chilca
# Processing Record 28 of Set 57 | teguldet
# Processing Record 29 of Set 57 | pampa
# Processing Record 30 of Set 57 | ilulissat
# Processing Record 31 of Set 57 | torbay
# Processing Record 32 of Set 57 | gobabis
# Processing Record 33 of Set 57 | khasan
# Processing Record 34 of Set 57 | kotido
# Processing Record 35 of Set 57 | souillac
# Processing Record 36 of Set 57 | bo
# City not found. Skipping...
# Processing Record 37 of Set 57 | linhares
# Processing Record 38 of Set 57 | krasne
# Processing Record 39 of Set 57 | cafarnaum
# Processing Record 40 of Set 57 | nipawin
# Processing Record 41 of Set 57 | atar
# Processing Record 42 of Set 57 | uni
# Processing Record 43 of Set 57 | mitu
# Processing Record 44 of Set 57 | mordovo
# Processing Record 45 of Set 57 | yanan
# City not found. Skipping...
# Processing Record 46 of Set 57 | aflu
# City not found. Skipping...
# Processing Record 47 of Set 57 | pacific grove
# Processing Record 48 of Set 57 | sakiai
# Processing Record 49 of Set 57 | rumuruti
# Processing Record 50 of Set 57 | vila velha
# Processing Record 1 of Set 58 | poso
# Processing Record 2 of Set 58 | basoko
# Processing Record 3 of Set 58 | castle rock
# Processing Record 4 of Set 58 | touros
# Processing Record 5 of Set 58 | tateyama
# Processing Record 6 of Set 58 | ust-maya
# Processing Record 7 of Set 58 | promyshlennaya
# Processing Record 29 of Set 59 | mbaiki
# Processing Record 30 of Set 59 | luanda
# Processing Record 31 of Set 59 | jonkoping
# Processing Record 32 of Set 59 | pevek
# Processing Record 33 of Set 59 | atlantic city
# Processing Record 34 of Set 59 | montelimar
# Processing Record 35 of Set 59 | mpanda
# Processing Record 36 of Set 59 | drumnadrochit
# Processing Record 37 of Set 59 | mudyuga
# City not found. Skipping...
# Processing Record 38 of Set 59 | nowy tomysl
# Processing Record 39 of Set 59 | svetlyy
# Processing Record 40 of Set 59 | zile
# Processing Record 41 of Set 59 | muli
# Processing Record 42 of Set 59 | vung tau
# Processing Record 43 of Set 59 | srednekolymsk
# Processing Record 44 of Set 59 | klaksvik
# Processing Record 45 of Set 59 | nouadhibou
# Processing Record 46 of Set 59 | misratah
# Processing Record 47 of Set 59 | san felipe
# Processing Record 48 of Set 59 | mongu
# Processing Record 49 of Set 59 | staryy nadym
# Processing Record 50 of Set 59 | portree
# Processing Record 1 of Set 60 | manjacaze
# Processing Record 2 of Set 60 | hualmay
# Processing Record 3 of Set 60 | grindavik
# Processing Record 4 of Set 60 | kalakamati
# Processing Record 5 of Set 60 | orsta
# Processing Record 6 of Set 60 | whitehorse
# Processing Record 7 of Set 60 | ossora
# Processing Record 8 of Set 60 | port blair
# Processing Record 9 of Set 60 | behbahan
# Processing Record 10 of Set 60 | vanimo
# Processing Record 11 of Set 60 | gornyy
# Processing Record 12 of Set 60 | cumaribo
# City not found. Skipping...
# Processing Record 13 of Set 60 | manthani
# Processing Record 14 of Set 60 | fourmies
# Processing Record 15 of Set 60 | miracema do tocantins
# Processing Record 16 of Set 60 | bouca
# Processing Record 17 of Set 60 | itarema
# Processing Record 18 of Set 60 | temaraia
# City not found. Skipping...
# Processing Record 19 of Set 60 | darab
# Processing Record 20 of Set 60 | utiroa
# City not found. Skipping...
# Processing Record 21 of Set 60 | lure
# Processing Record 22 of Set 60 | chicama
# Processing Record 23 of Set 60 | muleba
# Processing Record 24 of Set 60 | leshukonskoye
# Processing Record 25 of Set 60 | brae
# Processing Record 26 of Set 60 | maningrida
# Processing Record 27 of Set 60 | oni
# Processing Record 28 of Set 60 | roma
# Processing Record 29 of Set 60 | taywarah
# Processing Record 30 of Set 60 | ajdabiya
# Processing Record 31 of Set 60 | andselv
# City not found. Skipping...
# Processing Record 32 of Set 60 | hazorasp
# Processing Record 33 of Set 60 | moroto
# Processing Record 34 of Set 60 | aasiaat
# Processing Record 35 of Set 60 | taoudenni
# Processing Record 36 of Set 60 | bayangol
# Processing Record 37 of Set 60 | seoul
# Processing Record 38 of Set 60 | cockburn town
# Processing Record 39 of Set 60 | luganville
# Processing Record 40 of Set 60 | senneterre
# Processing Record 41 of Set 60 | kargopol
# Processing Record 42 of Set 60 | sumbawa
# City not found. Skipping...
# Processing Record 43 of Set 60 | ribeira brava
# Processing Record 44 of Set 60 | ugoofaaru
# Processing Record 45 of Set 60 | malumfashi
# Processing Record 46 of Set 60 | ewa beach
# Processing Record 47 of Set 60 | kearney
# Processing Record 48 of Set 60 | huarmey
# Processing Record 49 of Set 60 | saint george
# Processing Record 50 of Set 60 | deniliquin
# Processing Record 1 of Set 61 | dalianwan
# Processing Record 2 of Set 61 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 61 | marystown
# Processing Record 4 of Set 61 | leh
# Processing Record 5 of Set 61 | dauphin
# Processing Record 6 of Set 61 | cedral
# Processing Record 7 of Set 61 | powell river
# Processing Record 8 of Set 61 | cayenne
# Processing Record 9 of Set 61 | galesong
# Processing Record 10 of Set 61 | ubinskoye
# Processing Record 11 of Set 61 | glenwood springs
# Processing Record 12 of Set 61 | hobyo
# Processing Record 13 of Set 61 | teguise
# Processing Record 14 of Set 61 | mehamn
# Processing Record 15 of Set 61 | bontang
# Processing Record 16 of Set 61 | quipapa
# Processing Record 17 of Set 61 | kodinsk
# Processing Record 18 of Set 61 | luderitz
# Processing Record 19 of Set 61 | codrington
# Processing Record 20 of Set 61 | makushino
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 78.8,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'TO',
#   'Date': '2021-02-07 09:31:32'},
#  {'City': 'Nishihara',
#   'Lat': 26.1842,
#   'Lng': 127.7558,
#   'Max Temp': 66.2,
#   'Humidity': 52,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'JP',
#   'Date': '2021-02-07 09:35:01'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 77.11,
#   'Humidity': 74,
#   'Cloudiness': 49,
#   'Wind Speed': 11.3,
#   'Country': 'PF',
#   'Date': '2021-02-07 09:31:23'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 44.6,
#   'Humidity': 76,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'AR',
#   'Date': '2021-02-07 09:30:10'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 69.01,
#   'Humidity': 81,
#   'Cloudiness': 99,
#   'Wind Speed': 3,
#   'Country': 'ZA',
#   'Date': '2021-02-07 09:31:28'},
#  {'City': 'Mount Isa',
#   'Lat': -20.7333,
#   'Lng': 139.5,
#   'Max Temp': 82.4,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 9.22,
#   'Country': 'AU',
#   'Date': '2021-02-07 09:32:03'},
#  {'City': 'Antalaha',
#   'Lat': -14.9003,
#   'Lng': 50.2788,
#   'Max Temp': 84.94,
#   'Humidity': 63,
#   'Cloudiness': 47,
#   'Wind Speed': 7.4,
#   'Country': 'MG',
#   'Date': '2021-02-07 09:35:01'},
#  {'City': 'Honiara',
#   'Lat': -9.4333,
#   'Lng': 159.95,
#   'Max Temp': 78.78,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 6.44,
#   'Country': 'SB',
#   'Date': '2021-02-07 09:34:15'},
#  {'City': 'West Wendover',
#   'Lat': 40.7391,
#   'Lng': -114.0733,
#   'Max Temp': 48.2,
#   'Humidity': 20,
#   'Cloudiness': 1,
#   'Wind Speed': 12.66,
#   'Country': 'US',
#   'Date': '2021-02-07 09:32:09'},
#  {'City': 'Yantal',
#   'Lat': 56.8471,
#   'Lng': 105.2542,
#   'Max Temp': 22.15,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 10.11,
#   'Country': 'RU',
#   'Date': '2021-02-07 09:35:02'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 42.8,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'CL',
#   'Date': '2021-02-07 09:31:31'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 62.6,
#   'Humidity': 77,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': '2021-02-07 09:31:23'},
#  {'City': 'Taksimo',
#   'Lat': 56.3444,
#   'Lng': 114.8794,
#   'Max Temp': -8.07,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 1.23,
#   'Country': 'RU',
#   'Date': '2021-02-07 09:35:02'},
#  {'City': 'Mlonggo',
#   'Lat': -6.5333,
#   'Lng': 110.7,
#   'Max Temp': 80.6,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Country': 'ID',
#   'Date': '2021-02-07 09:35:02'},
#  {'City': 'Asau',
#   'Lat': 46.4333,
#   'Lng': 26.4,
#   'Max Temp': 28.99,
#   'Humidity': 74,
#   'Cloudiness': 98,
#   'Wind Speed': 4.52,
#   'Country': 'RO',
#   'Date': '2021-02-07 09:31:48'},
#  {'City': 'Methoni',
#   'Lat': 36.8197,
#   'Lng': 21.7049,
#   'Max Temp': 62.6,
#   'Humidity': 67,
#   'Cloudiness': 20,
#   'Wind Speed': 11.48,
#   'Country': 'GR',
#   'Date': '2021-02-07 09:35:02'},
#  {'City': 'Clyde River',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': -4,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 2.3,
#   'Country': 'CA',
#   'Date': '2021-02-07 09:31:24'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 73.4,
#   'Humidity': 53,
#   'Cloudiness': 20,
#   'Wind Speed': 21.85,
#   'Country': 'ZA',
#   'Date': '2021-02-07 09:30:16'},
#  {'City': 'Goderich',
#   'Lat': 43.7501,
#   'Lng': -81.7165,
#   'Max Temp': 19.4,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 13.8,
#   'Country': 'CA',
#   'Date': '2021-02-07 09:32:06'},
#  {'City': 'Fare',
#   'Lat': -16.7,
#   'Lng': -151.0167,
#   'Max Temp': 81.77,
#   'Humidity': 76,
#   'Cloudiness': 15,
#   'Wind Speed': 12.88,
#   'Country': 'PF',
#   'Date': '2021-02-07 09:35:03'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 62.01,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'AU',
#   'Date': '2021-02-07 09:31:25'},
#  {'City': 'Leningradskiy',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp': -11.61,
#   'Humidity': 72,
#   'Cloudiness': 11,
#   'Wind Speed': 4.72,
#   'Country': 'RU',
#   'Date': '2021-02-07 09:31:46'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 57.06,
#   'Humidity': 89,
#   'Cloudiness': 88,
#   'Wind Speed': 6.6,
#   'Country': 'NZ',
#   'Date': '2021-02-07 09:31:25'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 56.1,
#   'Humidity': 92,
#   'Cloudiness': 58,
#   'Wind Speed': 2.59,
#   'Country': 'NZ',
#   'Date': '2021-02-07 09:31:23'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 75.99,
#   'Humidity': 96,
#   'Cloudiness': 43,
#   'Wind Speed': 1.99,
#   'Country': 'EC',
#   'Date': '2021-02-07 09:31:37'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 19,
#   'Humidity': 55,
#   'Cloudiness': 100,
#   'Wind Speed': 0.87,
#   'Country': 'US',
#   'Date': '2021-02-07 09:31:23'},
#  {'City': 'Bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 28,
#   'Humidity': 79,
#   'Cloudiness': 1,
#   'Wind Speed': 3.42,
#   'Country': 'US',
#   'Date': '2021-02-07 09:31:29'},
#  {'City': 'Brooks',
#   'Lat': 50.5834,
#   'Lng': -111.8851,
#   'Max Temp': -13,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 5.75,
#   'Country': 'CA',
#   'Date': '2021-02-07 09:35:04'},
#  {'City': 'Teya',
#   'Lat': 60.3778,
#   'Lng': 92.6267,
#   'Max Temp': 32.38,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 7.92,
#   'Country': 'RU',
#   'Date': '2021-02-07 09:35:05'},
#  {'City': 'Araucaria',
#   'Lat': -25.5931,
#   'Lng': -49.4103,
#   'Max Temp': 61,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'BR',
#   'Date': '2021-02-07 09:34:49'},
#  {'City': 'Dubrovka',
#   'Lat': 53.6907,
#   'Lng': 33.5071,
#   'Max Temp': 6.8,
#   'Humidity': 72,
#   'Cloudiness': 20,
#   'Wind Speed': 11.18,
#   'Country': 'RU',
#   'Date': '2021-02-07 09:35:05'},
#  {'City': 'Enumclaw',
#   'Lat': 47.2043,
#   'Lng': -121.9915,
#   'Max Temp': 44.01,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 11.01,
#   'Country': 'US',
#   'Date': '2021-02-07 09:35:05'},
#  {'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 59,
#   'Humidity': 47,
#   'Cloudiness': 20,
#   'Wind Speed': 16.11,
#   'Country': 'AU',
#   'Date': '2021-02-07 09:29:16'},
#  {'City': 'Oriximina',
#   'Lat': -1.7656,
#   'Lng': -55.8661,
#   'Max Temp': 74.86,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 1.97,
#   'Country': 'BR',
#   'Date': '2021-02-07 09:32:00'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 86,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Country': 'AU',
#   'Date': '2021-02-07 09:31:58'},
#  {'City': 'Radchenko',
#   'Lat': 56.6803,
#   'Lng': 36.3718,
#   'Max Temp': 8.98,
#   'Humidity': 93,
#   'Cloudiness': 98,
#   'Wind Speed': 11.14,
#   'Country': 'RU',
#   'Date': '2021-02-07 09:35:06'},
#  {'City': 'Lenauheim',
#   'Lat': 45.8719,
#   'Lng': 20.7994,
#   'Max Temp': 54,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Country': 'RO',
#   'Date': '2021-02-07 09:35:06'},
#  {'City': 'Alofi',
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Max Temp': 78.8,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Country': 'NU',
#   'Date': '2021-02-07 09:35:06'},
#  {'City': 'Victoria',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 78.01,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'HK',
#   'Date': '2021-02-07 09:28:01'},
#  {'City': 'Henties Bay',
#   'Lat': -22.116,
#   'Lng': 14.2845,
#   'Max Temp': 66.99,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 5.99,
#   'Country': 'NA',
#   'Date': '2021-02-07 09:31:50'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 17.6,
#   'Humidity': 53,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': '2021-02-07 09:31:35'},
#  {'City': 'Jetalsar',
#   'Lat': 21.7,
#   'Lng': 70.5833,
#   'Max Temp': 86,
#   'Humidity': 22,
#   'Cloudiness': 0,
#   'Wind Speed': 7.36,
#   'Country': 'IN',
#   'Date': '2021-02-07 09:35:07'},
#  {'City': 'Sokolo',
#   'Lat': 14.7328,
#   'Lng': -6.1219,
#   'Max Temp': 75.45,
#   'Humidity': 21,
#   'Cloudiness': 100,
#   'Wind Speed': 19.51,
#   'Country': 'ML',
#   'Date': '2021-02-07 09:35:07'},
#  {'City': 'San Patricio',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 55.4,
#   'Humidity': 71,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': '2021-02-07 09:31:46'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 77,
#   'Humidity': 65,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Country': 'ZA',
#   'Date': '2021-02-07 09:30:01'},
#  {'City': 'Shush',
#   'Lat': 32.1942,
#   'Lng': 48.2436,
#   'Max Temp': 64.67,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 9.69,
#   'Country': 'IR',
#   'Date': '2021-02-07 09:34:28'},
#  {'City': 'Maldonado',
#   'Lat': -34.6667,
#   'Lng': -54.9167,
#   'Max Temp': 63,
#   'Humidity': 100,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Country': 'UY',
#   'Date': '2021-02-07 09:35:08'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 87.8,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 14.97,
#   'Country': 'MU',
#   'Date': '2021-02-07 09:31:30'},
#  {'City': 'Imeni Poliny Osipenko',
#   'Lat': 52.4201,
#   'Lng': 136.4853,
#   'Max Temp': 3.99,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 12.48,
#   'Country': 'RU',
#   'Date': '2021-02-07 09:35:08'},
#  {'City': 'Cozumel',
#   'Lat': 20.5083,
#   'Lng': -86.9458,
#   'Max Temp': 78.01,
#   'Humidity': 92,
#   'Cloudiness': 62,
#   'Wind Speed': 10.98,
#   'Country': 'MX',
#   'Date': '2021-02-07 09:35:08'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 73.4,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'BR',
#   'Date': '2021-02-07 09:31:25'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 56.79,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 3.65,
#   'Country': 'CL',
#   'Date': '2021-02-07 09:31:25'},
#  {'City': 'Flin Flon',
#   'Lat': 54.7682,
#   'Lng': -101.865,
#   'Max Temp': -37.26,
#   'Humidity': 79,
#   'Cloudiness': 19,
#   'Wind Speed': 8.14,
#   'Country': 'CA',
#   'Date': '2021-02-07 09:35:08'},
#  {'City': 'Svetlaya',
#   'Lat': 46.5389,
#   'Lng': 138.3297,
#   'Max Temp': 4.98,
#   'Humidity': 86,
#   'Cloudiness': 45,
#   'Wind Speed': 11.01,
#   'Country': 'RU',
#   'Date': '2021-02-07 09:35:09'},
#  {'City': 'Paragould',
#   'Lat': 36.0584,
#   'Lng': -90.4973,
#   'Max Temp': 30.2,
#   'Humidity': 80,
#   'Cloudiness': 90,
#   'Wind Speed': 9.22,
#   'Country': 'US',
#   'Date': '2021-02-07 09:35:06'},
#  {'City': 'Nanortalik',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 32.23,
#   'Humidity': 89,
#   'Cloudiness': 67,
#   'Wind Speed': 4.09,
#   'Country': 'GL',
#   'Date': '2021-02-07 09:32:04'},
#  {'City': 'Nhulunbuy',
#   'Lat': -12.2333,
#   'Lng': 136.7667,
#   'Max Temp': 78.8,
#   'Humidity': 89,
#   'Cloudiness': 95,
#   'Wind Speed': 9.22,
#   'Country': 'AU',
#   'Date': '2021-02-07 09:35:09'},
#  {'City': 'Parga',
#   'Lat': 39.2831,
#   'Lng': 20.3964,
#   'Max Temp': 60.8,
#   'Humidity': 82,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Country': 'GR',
#   'Date': '2021-02-07 09:35:09'},
#  {'City': 'Komsomolskiy',
#   'Lat': 40.4272,
#   'Lng': 71.7189,
#   'Max Temp': 53.6,
#   'Humidity': 37,
#   'Cloudiness': 83,
#   'Wind Speed': 6.91,
#   'Country': 'UZ',
#   'Date': '2021-02-07 09:35:09'},
#  {'City': 'Fairfield',
#   'Lat': 41.2668,
#   'Lng': -73.3162,
#   'Max Temp': 32,
#   'Humidity': 69,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Date': '2021-02-07 09:35:09'},
#  {'City': 'Lorengau',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 82.33,
#   'Humidity': 80,
#   'Cloudiness': 81,
#   'Wind Speed': 6.93,
#   'Country': 'PG',
#   'Date': '2021-02-07 09:32:39'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 68,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': '2021-02-07 09:31:27'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 66,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'AR',
#   'Date': '2021-02-07 09:31:27'},
#  {'City': 'Neftcala',
#   'Lat': 39.3742,
#   'Lng': 49.2472,
#   'Max Temp': 60.71,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 12.15,
#   'Country': 'AZ',
#   'Date': '2021-02-07 09:35:00'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': -27.11,
#   'Humidity': 87,
#   'Cloudiness': 91,
#   'Wind Speed': 9.6,
#   'Country': 'RU',
#   'Date': '2021-02-07 09:31:33'},
#  {'City': 'Yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': -45.99,
#   'Humidity': 73,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Country': 'CA',
#   'Date': '2021-02-07 09:31:33'},
#  {'City': 'Mount Gambier',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 60.8,
#   'Humidity': 63,
#   'Cloudiness': 90,
#   'Wind Speed': 16.11,
#   'Country': 'AU',
#   'Date': '2021-02-07 09:31:55'},
#  {'City': 'Port Hedland',
#   'Lat': -20.3167,
#   'Lng': 118.5667,
#   'Max Temp': 87.8,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 17.27,
#   'Country': 'AU',
#   'Date': '2021-02-07 09:31:18'},
#  {'City': 'Severo-Kurilsk',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 23.41,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 27.07,
#   'Country': 'RU',
#   'Date': '2021-02-07 09:32:21'},
#  {'City': 'Mogadishu',
#   'Lat': 2.0371,
#   'Lng': 45.3438,
#   'Max Temp': 84.2,
#   'Humidity': 58,
#   'Cloudiness': 40,
#   'Wind Speed': 20.71,
#   'Country': 'SO',
#   'Date': '2021-02-07 09:35:11'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': -15.59,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 16.69,
#   'Country': 'CA',
#   'Date': '2021-02-07 09:31:42'},
#  {'City': 'Belmonte',
#   'Lat': -15.8631,
#   'Lng': -38.8828,
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'BR',
#   'Date': '2021-02-07 09:35:11'},
#  {'City': 'Lavrentiya',
#   'Lat': 65.5833,
#   'Lng': -171,
#   'Max Temp': -12.46,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 4.68,
#   'Country': 'RU',
#   'Date': '2021-02-07 09:32:31'},
#  {'City': 'Hun',
#   'Lat': 29.1268,
#   'Lng': 15.9477,
#   'Max Temp': 77.54,
#   'Humidity': 16,
#   'Cloudiness': 100,
#   'Wind Speed': 17.27,
#   'Country': 'LY',
#   'Date': '2021-02-07 09:35:11'},
#  {'City': 'Quatre Cocos',
#   'Lat': -20.2078,
#   'Lng': 57.7625,
#   'Max Temp': 87.8,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 14.97,
#   'Country': 'MU',
#   'Date': '2021-02-07 09:31:25'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 60.8,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 12.66,
#   'Country': 'PT',
#   'Date': '2021-02-07 09:31:28'},
#  {'City': 'Nara',
#   'Lat': 34.6851,
#   'Lng': 135.8049,
#   'Max Temp': 53.6,
#   'Humidity': 54,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Country': 'JP',
#   'Date': '2021-02-07 09:35:12'},
#  {'City': 'Sao Filipe',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 69.19,
#   'Humidity': 71,
#   'Cloudiness': 19,
#   'Wind Speed': 14.74,
#   'Country': 'CV',
#   'Date': '2021-02-07 09:31:24'},
#  {'City': 'Simpang',
#   'Lat': -1.2667,
#   'Lng': 104.0833,
#   'Max Temp': 83.25,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 7.18,
#   'Country': 'ID',
#   'Date': '2021-02-07 09:35:12'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': -7.6,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'US',
#   'Date': '2021-02-07 09:31:24'},
#  {'City': 'Husavik',
#   'Lat': 66.0449,
#   'Lng': -17.3389,
#   'Max Temp': 33.8,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Country': 'IS',
#   'Date': '2021-02-07 09:32:18'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 89.6,
#   'Humidity': 58,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Country': 'MY',
#   'Date': '2021-02-07 09:30:07'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 79.32,
#   'Humidity': 76,
#   'Cloudiness': 70,
#   'Wind Speed': 21.85,
#   'Country': 'PF',
#   'Date': '2021-02-07 09:31:35'},
#  {'City': 'Eshowe',
#   'Lat': -28.8865,
#   'Lng': 31.4699,
#   'Max Temp': 82.36,
#   'Humidity': 66,
#   'Cloudiness': 62,
#   'Wind Speed': 11.77,
#   'Country': 'ZA',
#   'Date': '2021-02-07 09:35:12'},
#  {'City': 'Saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': -38.94,
#   'Humidity': 78,
#   'Cloudiness': 25,
#   'Wind Speed': 11.12,
#   'Country': 'RU',
#   'Date': '2021-02-07 09:32:19'},
#  {'City': 'Avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 78.8,
#   'Humidity': 83,
#   'Cloudiness': 6,
#   'Wind Speed': 3.44,
#   'Country': 'CK',
#   'Date': '2021-02-07 09:31:51'},
#  {'City': 'Tabas',
#   'Lat': 33.5959,
#   'Lng': 56.9244,
#   'Max Temp': 69.8,
#   'Humidity': 14,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Country': 'IR',
#   'Date': '2021-02-07 09:34:28'},
#  {'City': 'Corinto',
#   'Lat': 37.9407,
#   'Lng': 22.9573,
#   'Max Temp': 63,
#   'Humidity': 49,
#   'Cloudiness': 75,
#   'Wind Speed': 1.99,
#   'Country': 'GR',
#   'Date': '2021-02-07 09:34:36'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 14,
#   'Humidity': 85,
#   'Cloudiness': 75,
#   'Wind Speed': 15.66,
#   'Country': 'RU',
#   'Date': '2021-02-07 09:31:38'},
#  {'City': 'Khatanga',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': -31.59,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 8.55,
#   'Country': 'RU',
#   'Date': '2021-02-07 09:31:33'},
#  {'City': 'Vao',
#   'Lat': -22.6667,
#   'Lng': 167.4833,
#   'Max Temp': 77.95,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 11.18,
#   'Country': 'NC',
#   'Date': '2021-02-07 09:32:42'},
#  {'City': 'Marawi',
#   'Lat': 7.9986,
#   'Lng': 124.2928,
#   'Max Temp': 78.01,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Country': 'PH',
#   'Date': '2021-02-07 09:32:17'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 78.8,
#   'Humidity': 61,
#   'Cloudiness': 40,
#   'Wind Speed': 24.16,
#   'Country': 'ZA',
#   'Date': '2021-02-07 09:30:07'},
#  {'City': 'Nehe',
#   'Lat': 48.4833,
#   'Lng': 124.8333,
#   'Max Temp': -4.81,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 5.32,
#   'Country': 'CN',
#   'Date': '2021-02-07 09:35:15'},
#  {'City': 'Baft',
#   'Lat': 29.234,
#   'Lng': 56.6057,
#   'Max Temp': 53.8,
#   'Humidity': 34,
#   'Cloudiness': 56,
#   'Wind Speed': 9.1,
#   'Country': 'IR',
#   'Date': '2021-02-07 09:35:15'},
#  {'City': 'Narsaq',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 41,
#   'Humidity': 30,
#   'Cloudiness': 75,
#   'Wind Speed': 44.87,
#   'Country': 'GL',
#   'Date': '2021-02-07 09:31:36'},
#  {'City': 'Patti',
#   'Lat': 31.2808,
#   'Lng': 74.8572,
#   'Max Temp': 71.6,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'IN',
#   'Date': '2021-02-07 09:35:15'},
#  {'City': 'Ust-Kuyga',
#   'Lat': 70.0167,
#   'Lng': 135.6,
#   'Max Temp': -29.31,
#   'Humidity': 82,
#   'Cloudiness': 32,
#   'Wind Speed': 4.76,
#   'Country': 'RU',
#   'Date': '2021-02-07 09:35:15'},
#  {'City': 'Haines Junction',
#   'Lat': 60.7522,
#   'Lng': -137.5108,
#   'Max Temp': -18.4,
#   'Humidity': 69,
#   'Cloudiness': 95,
#   'Wind Speed': 1.14,
#   'Country': 'CA',
#   'Date': '2021-02-07 09:32:18'},
#  {'City': 'Perdoes',
#   'Lat': -21.0908,
#   'Lng': -45.0914,
#   'Max Temp': 62.08,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 5.46,
#   'Country': 'BR',
#   'Date': '2021-02-07 09:34:50'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 59,
#   'Humidity': 63,
#   'Cloudiness': 88,
#   'Wind Speed': 1.01,
#   'Country': 'PT',
#   'Date': '2021-02-07 09:31:49'},
#  {'City': 'Okha',
#   'Lat': 53.5739,
#   'Lng': 142.9478,
#   'Max Temp': 7.29,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 20.07,
#   'Country': 'RU',
#   'Date': '2021-02-07 09:35:16'},
#  {'City': 'Muros',
#   'Lat': 42.7762,
#   'Lng': -9.0603,
#   'Max Temp': 44.01,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Country': 'ES',
#   'Date': '2021-02-07 09:35:16'},
#  {'City': 'Qostanay',
#   'Lat': 53.1667,
#   'Lng': 63.5833,
#   'Max Temp': 10.4,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 35.79,
#   'Country': 'KZ',
#   'Date': '2021-02-07 09:35:16'},
#  {'City': 'Isangel',
#   'Lat': -19.55,
#   'Lng': 169.2667,
#   'Max Temp': 79.43,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 4.41,
#   'Country': 'VU',
#   'Date': '2021-02-07 09:27:59'},
#  {'City': 'Tucuman',
#   'Lat': -26.8241,
#   'Lng': -65.2226,
#   'Max Temp': 66.2,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'AR',
#   'Date': '2021-02-07 09:32:44'},
#  {'City': 'Ambilobe',
#   'Lat': -13.2,
#   'Lng': 49.05,
#   'Max Temp': 87.3,
#   'Humidity': 65,
#   'Cloudiness': 99,
#   'Wind Speed': 5.61,
#   'Country': 'MG',
#   'Date': '2021-02-07 09:32:40'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 69.8,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Country': 'ZA',
#   'Date': '2021-02-07 09:31:40'},
#  {'City': 'Huangzhou',
#   'Lat': 30.45,
#   'Lng': 114.8,
#   'Max Temp': 50,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 4.47,
#   'Country': 'CN',
#   'Date': '2021-02-07 09:34:53'},
#  {'City': 'Aklavik',
#   'Lat': 68.2191,
#   'Lng': -135.0107,
#   'Max Temp': -13,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 5.75,
#   'Country': 'CA',
#   'Date': '2021-02-07 09:31:48'},
#  {'City': 'Berlevag',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 24.15,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 21.16,
#   'Country': 'NO',
#   'Date': '2021-02-07 09:32:42'},
#  {'City': 'Athabasca',
#   'Lat': 54.7169,
#   'Lng': -113.2854,
#   'Max Temp': -40,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Country': 'CA',
#   'Date': '2021-02-07 09:32:38'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 75.99,
#   'Humidity': 76,
#   'Cloudiness': 41,
#   'Wind Speed': 5.01,
#   'Country': 'ZA',
#   'Date': '2021-02-07 09:31:27'},
#  {'City': 'Terrak',
#   'Lat': 65.087,
#   'Lng': 12.3715,
#   'Max Temp': 24.8,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'NO',
#   'Date': '2021-02-07 09:35:18'},
#  {'City': 'Olawa',
#   'Lat': 50.9466,
#   'Lng': 17.2926,
#   'Max Temp': 21.99,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 5.01,
#   'Country': 'PL',
#   'Date': '2021-02-07 09:34:39'},
#  {'City': 'Yeppoon',
#   'Lat': -23.1333,
#   'Lng': 150.7333,
#   'Max Temp': 87.8,
#   'Humidity': 58,
#   'Cloudiness': 95,
#   'Wind Speed': 12.66,
#   'Country': 'AU',
#   'Date': '2021-02-07 09:35:18'},
#  {'City': 'Monster',
#   'Lat': 52.0258,
#   'Lng': 4.175,
#   'Max Temp': 26.01,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 25.32,
#   'Country': 'NL',
#   'Date': '2021-02-07 09:35:18'},
#  {'City': 'Ossipee',
#   'Lat': 43.6854,
#   'Lng': -71.1167,
#   'Max Temp': 15.01,
#   'Humidity': 76,
#   'Cloudiness': 92,
#   'Wind Speed': 2.3,
#   'Country': 'US',
#   'Date': '2021-02-07 09:35:19'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 23,
#   'Humidity': 68,
#   'Cloudiness': 1,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Date': '2021-02-07 09:31:39'},
#  {'City': 'Bonavista',
#   'Lat': 48.6499,
#   'Lng': -53.1147,
#   'Max Temp': 32,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Country': 'CA',
#   'Date': '2021-02-07 09:31:47'},
#  {'City': 'Salamiyah',
#   'Lat': 35.0113,
#   'Lng': 37.0532,
#   'Max Temp': 64.56,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 11.72,
#   'Country': 'SY',
#   'Date': '2021-02-07 09:34:40'},
#  {'City': 'Ayan',
#   'Lat': 56.45,
#   'Lng': 138.1667,
#   'Max Temp': -3.41,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 19.71,
#   'Country': 'RU',
#   'Date': '2021-02-07 09:35:19'},
#  {'City': 'Beringovskiy',
#   'Lat': 63.05,
#   'Lng': 179.3167,
#   'Max Temp': -6.97,
#   'Humidity': 91,
#   'Cloudiness': 99,
#   'Wind Speed': 12.91,
#   'Country': 'RU',
#   'Date': '2021-02-07 09:32:15'},
#  {'City': 'Starokozache',
#   'Lat': 46.3372,
#   'Lng': 29.9853,
#   'Max Temp': 28,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 11.18,
#   'Country': 'UA',
#   'Date': '2021-02-07 09:35:19'},
#  {'City': 'Nelson Bay',
#   'Lat': -32.7167,
#   'Lng': 152.15,
#   'Max Temp': 73.4,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'AU',
#   'Date': '2021-02-07 09:35:19'},
#  {'City': 'Inhambane',
#   'Lat': -23.865,
#   'Lng': 35.3833,
#   'Max Temp': 89.6,
#   'Humidity': 58,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'MZ',
#   'Date': '2021-02-07 09:31:33'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 57.99,
#   'Humidity': 54,
#   'Cloudiness': 4,
#   'Wind Speed': 1.01,
#   'Country': 'AU',
#   'Date': '2021-02-07 09:31:33'},
#  {'City': 'Nome',
#   'Lat': 64.5011,
#   'Lng': -165.4064,
#   'Max Temp': 10.4,
#   'Humidity': 85,
#   'Cloudiness': 90,
#   'Wind Speed': 3.49,
#   'Country': 'US',
#   'Date': '2021-02-07 09:31:44'},
#  {'City': 'Hofn',
#   'Lat': 64.2539,
#   'Lng': -15.2082,
#   'Max Temp': 34.14,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 16.33,
#   'Country': 'IS',
#   'Date': '2021-02-07 09:35:20'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 85.26,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 12.3,
#   'Country': 'ID',
#   'Date': '2021-02-07 09:27:00'},
#  {'City': 'Mahebourg',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 87.8,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 14.97,
#   'Country': 'MU',
#   'Date': '2021-02-07 09:32:01'},
#  {'City': 'Wachtersbach',
#   'Lat': 50.2551,
#   'Lng': 9.2956,
#   'Max Temp': 37,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 10.94,
#   'Country': 'DE',
#   'Date': '2021-02-07 09:35:20'},
#  {'City': 'Grand Gaube',
#   'Lat': -20.0064,
#   'Lng': 57.6608,
#   'Max Temp': 84.99,
#   'Humidity': 72,
#   'Cloudiness': 44,
#   'Wind Speed': 10,
#   'Country': 'MU',
#   'Date': '2021-02-07 09:32:30'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': -27.78,
#   'Humidity': 84,
#   'Cloudiness': 0,
#   'Wind Speed': 4.74,
#   'Country': 'RU',
#   'Date': '2021-02-07 09:31:22'},
#  {'City': 'Pisco',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 71.6,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 0.87,
#   'Country': 'PE',
#   'Date': '2021-02-07 09:31:43'},
#  {'City': 'Akyab',
#   'Lat': 20.15,
#   'Lng': 92.9,
#   'Max Temp': 81.27,
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 21.21,
#   'Country': 'MM',
#   'Date': '2021-02-07 09:31:53'},
#  {'City': 'Bonnyville',
#   'Lat': 54.2668,
#   'Lng': -110.735,
#   'Max Temp': -32.8,
#   'Humidity': 75,
#   'Cloudiness': 1,
#   'Wind Speed': 2.51,
#   'Country': 'CA',
#   'Date': '2021-02-07 09:35:21'},
#  {'City': 'Bathsheba',
#   'Lat': 13.2167,
#   'Lng': -59.5167,
#   'Max Temp': 78.8,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 20.71,
#   'Country': 'BB',
#   'Date': '2021-02-07 09:32:44'},
#  {'City': 'Kloulklubed',
#   'Lat': 7.0419,
#   'Lng': 134.2556,
#   'Max Temp': 80.6,
#   'Humidity': 89,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'PW',
#   'Date': '2021-02-07 09:32:34'},
#  {'City': 'Eyl',
#   'Lat': 7.9803,
#   'Lng': 49.8164,
#   'Max Temp': 85.28,
#   'Humidity': 47,
#   'Cloudiness': 35,
#   'Wind Speed': 19.13,
#   'Country': 'SO',
#   'Date': '2021-02-07 09:32:32'},
#  {'City': 'Bakchar',
#   'Lat': 57.0186,
#   'Lng': 82.0711,
#   'Max Temp': 32.72,
#   'Humidity': 94,
#   'Cloudiness': 95,
#   'Wind Speed': 17.83,
#   'Country': 'RU',
#   'Date': '2021-02-07 09:35:21'},
#  {'City': 'Sao Jose Da Coroa Grande',
#   'Lat': -8.8978,
#   'Lng': -35.1478,
#   'Max Temp': 80.13,
#   'Humidity': 76,
#   'Cloudiness': 43,
#   'Wind Speed': 8.86,
#   'Country': 'BR',
#   'Date': '2021-02-07 09:35:21'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 32,
#   'Humidity': 55,
#   'Cloudiness': 20,
#   'Wind Speed': 17.27,
#   'Country': 'GL',
#   'Date': '2021-02-07 09:31:58'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 57.99,
#   'Humidity': 72,
#   'Cloudiness': 53,
#   'Wind Speed': 4.18,
#   'Country': 'MX',
#   'Date': '2021-02-07 09:32:10'},
#  {'City': 'Valparaiso',
#   'Lat': -33.0393,
#   'Lng': -71.6273,
#   'Max Temp': 60.8,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'CL',
#   'Date': '2021-02-07 09:35:22'},
#  {'City': 'Unguia',
#   'Lat': 8.0434,
#   'Lng': -77.0945,
#   'Max Temp': 75.61,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 1.66,
#   'Country': 'CO',
#   'Date': '2021-02-07 09:35:22'},
#  {'City': 'Gambissara',
#   'Lat': 13.2382,
#   'Lng': -14.3108,
#   'Max Temp': 77.38,
#   'Humidity': 19,
#   'Cloudiness': 4,
#   'Wind Speed': 12.41,
#   'Country': 'SN',
#   'Date': '2021-02-07 09:35:22'},
#  {'City': 'Xingyi',
#   'Lat': 24.1877,
#   'Lng': 102.817,
#   'Max Temp': 50.16,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 2.3,
#   'Country': 'CN',
#   'Date': '2021-02-07 09:35:22'},
#  {'City': 'Priladozhskiy',
#   'Lat': 59.85,
#   'Lng': 31.4833,
#   'Max Temp': 14,
#   'Humidity': 48,
#   'Cloudiness': 100,
#   'Wind Speed': 10.83,
#   'Country': 'RU',
#   'Date': '2021-02-07 09:35:22'},
#  {'City': 'Cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 67.19,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 10.89,
#   'Country': 'BR',
#   'Date': '2021-02-07 09:32:00'},
#  {'City': 'Vardo',
#   'Lat': 70.3705,
#   'Lng': 31.1107,
#   'Max Temp': 25.32,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 25.19,
#   'Country': 'NO',
#   'Date': '2021-02-07 09:31:29'},
#  {'City': 'Ketchikan',
#   'Lat': 55.3422,
#   'Lng': -131.6461,
#   'Max Temp': 32,
#   'Humidity': 74,
#   'Cloudiness': 1,
#   'Wind Speed': 14.97,
#   'Country': 'US',
#   'Date': '2021-02-07 09:32:27'},
#  {'City': 'Padang',
#   'Lat': -0.9492,
#   'Lng': 100.3543,
#   'Max Temp': 91.4,
#   'Humidity': 55,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'ID',
#   'Date': '2021-02-07 09:31:49'},
#  {'City': 'Olafsvik',
#   'Lat': 64.8945,
#   'Lng': -23.7142,
#   'Max Temp': 33.33,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 14.38,
#   'Country': 'IS',
#   'Date': '2021-02-07 09:32:28'},
#  {'City': 'Vila Franca Do Campo',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 60.01,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 24.16,
#   'Country': 'PT',
#   'Date': '2021-02-07 09:31:38'},
#  {'City': 'Kampene',
#   'Lat': -3.6,
#   'Lng': 26.6667,
#   'Max Temp': 81.45,
#   'Humidity': 79,
#   'Cloudiness': 62,
#   'Wind Speed': 2.06,
#   'Country': 'CD',
#   'Date': '2021-02-07 09:34:36'},
#  {'City': 'Saint-Pierre',
#   'Lat': -21.3393,
#   'Lng': 55.4781,
#   'Max Temp': 87.8,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'RE',
#   'Date': '2021-02-07 09:34:34'},
#  {'City': 'Kawalu',
#   'Lat': -7.3817,
#   'Lng': 108.2082,
#   'Max Temp': 75.85,
#   'Humidity': 88,
#   'Cloudiness': 96,
#   'Wind Speed': 1.48,
#   'Country': 'ID',
#   'Date': '2021-02-07 09:35:23'},
#  {'City': 'Beaverlodge',
#   'Lat': 55.2166,
#   'Lng': -119.4361,
#   'Max Temp': -41.8,
#   'Humidity': 66,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'CA',
#   'Date': '2021-02-07 09:35:24'},
#  {'City': 'Ulaangom',
#   'Lat': 49.9811,
#   'Lng': 92.0667,
#   'Max Temp': -1.28,
#   'Humidity': 91,
#   'Cloudiness': 95,
#   'Wind Speed': 0.74,
#   'Country': 'MN',
#   'Date': '2021-02-07 09:35:24'},
#  {'City': 'Saint-Augustin',
#   'Lat': 51.226,
#   'Lng': -58.6502,
#   'Max Temp': 26.04,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 19.01,
#   'Country': 'CA',
#   'Date': '2021-02-07 09:32:21'},
#  {'City': 'Coihaique',
#   'Lat': -45.5752,
#   'Lng': -72.0662,
#   'Max Temp': 50,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'CL',
#   'Date': '2021-02-07 09:35:25'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 10.24,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 1.92,
#   'Country': 'GL',
#   'Date': '2021-02-07 09:31:29'},
#  {'City': 'Gigmoto',
#   'Lat': 13.7796,
#   'Lng': 124.39,
#   'Max Temp': 79.41,
#   'Humidity': 84,
#   'Cloudiness': 83,
#   'Wind Speed': 13.29,
#   'Country': 'PH',
#   'Date': '2021-02-07 09:35:25'},
#  {'City': 'Katsuura',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 53.6,
#   'Humidity': 82,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Country': 'JP',
#   'Date': '2021-02-07 09:32:27'},
#  {'City': 'Upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 21.7,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 6.31,
#   'Country': 'GL',
#   'Date': '2021-02-07 09:31:57'},
#  {'City': 'Norman Wells',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': -20.2,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Country': 'CA',
#   'Date': '2021-02-07 09:31:39'},
#  {'City': 'Acheng',
#   'Lat': 45.5454,
#   'Lng': 126.977,
#   'Max Temp': 3.2,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 6.71,
#   'Country': 'CN',
#   'Date': '2021-02-07 09:34:54'},
#  {'City': 'Talnakh',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': -27.83,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 2.89,
#   'Country': 'RU',
#   'Date': '2021-02-07 09:31:23'},
#  {'City': 'Dingle',
#   'Lat': 10.9995,
#   'Lng': 122.6711,
#   'Max Temp': 77.38,
#   'Humidity': 88,
#   'Cloudiness': 49,
#   'Wind Speed': 10.33,
#   'Country': 'PH',
#   'Date': '2021-02-07 09:31:45'},
#  {'City': 'Ponta Delgada',
#   'Lat': 37.7333,
#   'Lng': -25.6667,
#   'Max Temp': 60.01,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 24.16,
#   'Country': 'PT',
#   'Date': '2021-02-07 09:35:26'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 81.37,
#   'Humidity': 81,
#   'Cloudiness': 57,
#   'Wind Speed': 18.43,
#   'Country': 'KI',
#   'Date': '2021-02-07 09:31:47'},
#  {'City': 'Kutum',
#   'Lat': 14.2,
#   'Lng': 24.6667,
#   'Max Temp': 71.55,
#   'Humidity': 20,
#   'Cloudiness': 24,
#   'Wind Speed': 14.81,
#   'Country': 'SD',
#   'Date': '2021-02-07 09:35:26'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 82.74,
#   'Humidity': 70,
#   'Cloudiness': 60,
#   'Wind Speed': 10.94,
#   'Country': 'MV',
#   'Date': '2021-02-07 09:31:47'},
#  {'City': 'Tarifa',
#   'Lat': 36.0139,
#   'Lng': -5.607,
#   'Max Temp': 55.4,
#   'Humidity': 82,
#   'Cloudiness': 20,
#   'Wind Speed': 20.71,
#   'Country': 'ES',
#   'Date': '2021-02-07 09:34:44'},
#  {'City': 'Reconquista',
#   'Lat': -29.15,
#   'Lng': -59.65,
#   'Max Temp': 62.33,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 5.23,
#   'Country': 'AR',
#   'Date': '2021-02-07 09:35:15'},
#  {'City': 'Manta',
#   'Lat': -0.95,
#   'Lng': -80.7333,
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'EC',
#   'Date': '2021-02-07 09:35:02'},
#  {'City': 'Avera',
#   'Lat': 33.194,
#   'Lng': -82.5271,
#   'Max Temp': 39.2,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': '2021-02-07 09:31:58'},
#  {'City': 'Dandong',
#   'Lat': 40.1292,
#   'Lng': 124.3947,
#   'Max Temp': 20.75,
#   'Humidity': 84,
#   'Cloudiness': 0,
#   'Wind Speed': 15.48,
#   'Country': 'CN',
#   'Date': '2021-02-07 09:31:45'},
#  {'City': 'Bambui',
#   'Lat': -20.0064,
#   'Lng': -45.9769,
#   'Max Temp': 68.41,
#   'Humidity': 90,
#   'Cloudiness': 79,
#   'Wind Speed': 2.26,
#   'Country': 'BR',
#   'Date': '2021-02-07 09:35:27'},
#  {'City': 'Goure',
#   'Lat': 13.9835,
#   'Lng': 10.2704,
#   'Max Temp': 75.99,
#   'Humidity': 15,
#   'Cloudiness': 51,
#   'Wind Speed': 8.01,
#   'Country': 'NE',
#   'Date': '2021-02-07 09:35:27'},
#  {'City': 'Xam Nua',
#   'Lat': 20.4197,
#   'Lng': 104.0439,
#   'Max Temp': 71.94,
#   'Humidity': 63,
#   'Cloudiness': 69,
#   'Wind Speed': 3.4,
#   'Country': 'LA',
#   'Date': '2021-02-07 09:35:27'},
#  {'City': 'Savannah Bight',
#   'Lat': 16.45,
#   'Lng': -85.85,
#   'Max Temp': 79,
#   'Humidity': 90,
#   'Cloudiness': 0,
#   'Wind Speed': 3,
#   'Country': 'HN',
#   'Date': '2021-02-07 09:35:27'},
#  {'City': 'College',
#   'Lat': 64.8569,
#   'Lng': -147.8028,
#   'Max Temp': -4,
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind Speed': 2.21,
#   'Country': 'US',
#   'Date': '2021-02-07 09:32:07'},
#  {'City': 'Eregli',
#   'Lat': 37.5133,
#   'Lng': 34.0467,
#   'Max Temp': 61.81,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 3.04,
#   'Country': 'TR',
#   'Date': '2021-02-07 09:35:27'},
#  {'City': 'Akdepe',
#   'Lat': 42.0551,
#   'Lng': 59.3788,
#   'Max Temp': 53.6,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Country': 'TM',
#   'Date': '2021-02-07 09:35:28'},
#  {'City': 'Kaitangata',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 61,
#   'Humidity': 90,
#   'Cloudiness': 31,
#   'Wind Speed': 3,
#   'Country': 'NZ',
#   'Date': '2021-02-07 09:32:10'},
#  {'City': 'Nemuro',
#   'Lat': 43.3236,
#   'Lng': 145.575,
#   'Max Temp': 17.6,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'JP',
#   'Date': '2021-02-07 09:35:28'},
#  {'City': 'Selishche',
#   'Lat': 56.8879,
#   'Lng': 33.2691,
#   'Max Temp': 9.82,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 10.02,
#   'Country': 'RU',
#   'Date': '2021-02-07 09:35:28'},
#  {'City': 'Luzhou',
#   'Lat': 28.8724,
#   'Lng': 105.4405,
#   'Max Temp': 65.66,
#   'Humidity': 39,
#   'Cloudiness': 83,
#   'Wind Speed': 3.98,
#   'Country': 'CN',
#   'Date': '2021-02-07 09:35:20'},
#  {'City': 'Lompoc',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 55,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': '2021-02-07 09:31:38'},
#  {'City': 'Gohpur',
#   'Lat': 26.8833,
#   'Lng': 93.6333,
#   'Max Temp': 80.6,
#   'Humidity': 41,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'IN',
#   'Date': '2021-02-07 09:35:28'},
#  {'City': 'Geraldton',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 73.4,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 19.57,
#   'Country': 'AU',
#   'Date': '2021-02-07 09:33:15'},
#  {'City': 'Weligama',
#   'Lat': 5.9667,
#   'Lng': 80.4167,
#   'Max Temp': 84.51,
#   'Humidity': 68,
#   'Cloudiness': 41,
#   'Wind Speed': 3.51,
#   'Country': 'LK',
#   'Date': '2021-02-07 09:35:29'},
#  {'City': 'Salalah',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 78.8,
#   'Humidity': 53,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'OM',
#   'Date': '2021-02-07 09:30:39'},
#  {'City': 'Kamiiso',
#   'Lat': 41.8167,
#   'Lng': 140.65,
#   'Max Temp': 24.8,
#   'Humidity': 58,
#   'Cloudiness': 40,
#   'Wind Speed': 19.57,
#   'Country': 'JP',
#   'Date': '2021-02-07 09:35:29'},
#  {'City': 'Flinders',
#   'Lat': -34.5833,
#   'Lng': 150.8552,
#   'Max Temp': 72,
#   'Humidity': 76,
#   'Cloudiness': 33,
#   'Wind Speed': 1.01,
#   'Country': 'AU',
#   'Date': '2021-02-07 09:31:29'},
#  {'City': 'Ilhabela',
#   'Lat': -23.7781,
#   'Lng': -45.3581,
#   'Max Temp': 72.88,
#   'Humidity': 80,
#   'Cloudiness': 52,
#   'Wind Speed': 3.18,
#   'Country': 'BR',
#   'Date': '2021-02-07 09:34:48'},
#  {'City': 'Kihei',
#   'Lat': 20.785,
#   'Lng': -156.4656,
#   'Max Temp': 64.99,
#   'Humidity': 77,
#   'Cloudiness': 20,
#   'Wind Speed': 5.19,
#   'Country': 'US',
#   'Date': '2021-02-07 09:35:29'},
#  {'City': 'Bubaque',
#   'Lat': 11.2833,
#   'Lng': -15.8333,
#   'Max Temp': 74.91,
#   'Humidity': 49,
#   'Cloudiness': 25,
#   'Wind Speed': 18.81,
#   'Country': 'GW',
#   'Date': '2021-02-07 09:31:39'},
#  {'City': 'Sitka',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 28.4,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': '2021-02-07 09:31:55'},
#  {'City': 'Wakkanai',
#   'Lat': 45.4094,
#   'Lng': 141.6739,
#   'Max Temp': 6.8,
#   'Humidity': 85,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Country': 'JP',
#   'Date': '2021-02-07 09:30:44'},
#  {'City': 'Kosa',
#   'Lat': 59.9445,
#   'Lng': 54.9977,
#   'Max Temp': -8.1,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 8.37,
#   'Country': 'RU',
#   'Date': '2021-02-07 09:35:30'},
#  {'City': 'Yerbogachen',
#   'Lat': 61.2767,
#   'Lng': 108.0108,
#   'Max Temp': 12.92,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 7.63,
#   'Country': 'RU',
#   'Date': '2021-02-07 09:32:07'},
#  {'City': 'Bedesa',
#   'Lat': 8.9,
#   'Lng': 40.7833,
#   'Max Temp': 67.66,
#   'Humidity': 54,
#   'Cloudiness': 88,
#   'Wind Speed': 4.07,
#   'Country': 'ET',
#   'Date': '2021-02-07 09:34:19'},
#  {'City': 'Surt',
#   'Lat': 31.2089,
#   'Lng': 16.5887,
#   'Max Temp': 72.72,
#   'Humidity': 26,
#   'Cloudiness': 100,
#   'Wind Speed': 15.99,
#   'Country': 'LY',
#   'Date': '2021-02-07 09:34:52'},
#  {'City': 'Faanui',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 82.04,
#   'Humidity': 73,
#   'Cloudiness': 23,
#   'Wind Speed': 11.83,
#   'Country': 'PF',
#   'Date': '2021-02-07 09:32:01'},
#  {'City': 'Naze',
#   'Lat': 28.3667,
#   'Lng': 129.4833,
#   'Max Temp': 60.8,
#   'Humidity': 67,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Country': 'JP',
#   'Date': '2021-02-07 09:32:02'},
#  {'City': 'Rio Grande',
#   'Lat': -32.035,
#   'Lng': -52.0986,
#   'Max Temp': 66,
#   'Humidity': 97,
#   'Cloudiness': 4,
#   'Wind Speed': 6.02,
#   'Country': 'BR',
#   'Date': '2021-02-07 09:34:51'},
#  {'City': 'Hami',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': 42.91,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 4.38,
#   'Country': 'CN',
#   'Date': '2021-02-07 09:35:31'},
#  {'City': 'Ust-Ilimsk',
#   'Lat': 58.0006,
#   'Lng': 102.6619,
#   'Max Temp': 26.76,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 7.67,
#   'Country': 'RU',
#   'Date': '2021-02-07 09:35:31'},
#  {'City': 'Provideniya',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': -4.22,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 13.29,
#   'Country': 'RU',
#   'Date': '2021-02-07 09:31:44'},
#  {'City': 'Beloha',
#   'Lat': -25.1667,
#   'Lng': 45.05,
#   'Max Temp': 89.28,
#   'Humidity': 54,
#   'Cloudiness': 74,
#   'Wind Speed': 7.85,
#   'Country': 'MG',
#   'Date': '2021-02-07 09:35:25'},
#  {'City': 'Hokitika',
#   'Lat': -42.7167,
#   'Lng': 170.9667,
#   'Max Temp': 58.77,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 2.06,
#   'Country': 'NZ',
#   'Date': '2021-02-07 09:35:32'},
#  {'City': 'Petrolina',
#   'Lat': -9.3986,
#   'Lng': -40.5008,
#   'Max Temp': 77,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'BR',
#   'Date': '2021-02-07 09:34:51'},
#  {'City': 'Shimorskoye',
#   'Lat': 55.3244,
#   'Lng': 42.0267,
#   'Max Temp': 1.27,
#   'Humidity': 90,
#   'Cloudiness': 99,
#   'Wind Speed': 11.32,
#   'Country': 'RU',
#   'Date': '2021-02-07 09:35:32'},
#  {'City': 'Serov',
#   'Lat': 59.6033,
#   'Lng': 60.5787,
#   'Max Temp': -8.95,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 5.77,
#   'Country': 'RU',
#   'Date': '2021-02-07 09:35:20'},
#  {'City': 'Eastbourne',
#   'Lat': 50.7687,
#   'Lng': 0.2845,
#   'Max Temp': 34,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Country': 'GB',
#   'Date': '2021-02-07 09:35:32'},
#  {'City': 'Awjilah',
#   'Lat': 29.1081,
#   'Lng': 21.2869,
#   'Max Temp': 74.86,
#   'Humidity': 22,
#   'Cloudiness': 60,
#   'Wind Speed': 13.67,
#   'Country': 'LY',
#   'Date': '2021-02-07 09:35:32'},
#  {'City': 'Milkovo',
#   'Lat': 54.7167,
#   'Lng': 158.6167,
#   'Max Temp': 22.93,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 6.13,
#   'Country': 'RU',
#   'Date': '2021-02-07 09:35:33'},
#  {'City': 'Broome',
#   'Lat': 42.2506,
#   'Lng': -75.833,
#   'Max Temp': 19.4,
#   'Humidity': 45,
#   'Cloudiness': 1,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Date': '2021-02-07 09:32:07'},
#  {'City': 'China',
#   'Lat': 25.7,
#   'Lng': -99.2333,
#   'Max Temp': 58.1,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 3.04,
#   'Country': 'MX',
#   'Date': '2021-02-07 09:35:33'},
#  {'City': 'Sambava',
#   'Lat': -14.2667,
#   'Lng': 50.1667,
#   'Max Temp': 85.03,
#   'Humidity': 64,
#   'Cloudiness': 72,
#   'Wind Speed': 8.32,
#   'Country': 'MG',
#   'Date': '2021-02-07 09:31:38'},
#  {'City': 'Ancud',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp': 51.01,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'CL',
#   'Date': '2021-02-07 09:31:35'},
#  {'City': 'Anadyr',
#   'Lat': 64.75,
#   'Lng': 177.4833,
#   'Max Temp': -7.01,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Date': '2021-02-07 09:32:35'},
#  {'City': 'Fortuna',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 46.99,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 4.34,
#   'Country': 'US',
#   'Date': '2021-02-07 09:32:28'},
#  {'City': 'Mandalgovi',
#   'Lat': 45.7625,
#   'Lng': 106.2708,
#   'Max Temp': 16.34,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 9.35,
#   'Country': 'MN',
#   'Date': '2021-02-07 09:34:41'},
#  {'City': 'Esmeralda',
#   'Lat': 21.8525,
#   'Lng': -78.1169,
#   'Max Temp': 69.8,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'CU',
#   'Date': '2021-02-07 09:35:34'},
#  {'City': 'Hammerfest',
#   'Lat': 70.6634,
#   'Lng': 23.6821,
#   'Max Temp': 24.8,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 20.71,
#   'Country': 'NO',
#   'Date': '2021-02-07 09:35:34'},
#  {'City': 'Elesbao Veloso',
#   'Lat': -6.2019,
#   'Lng': -42.1403,
#   'Max Temp': 75.11,
#   'Humidity': 79,
#   'Cloudiness': 77,
#   'Wind Speed': 1.52,
#   'Country': 'BR',
#   'Date': '2021-02-07 09:35:34'},
#  {'City': 'Sistranda',
#   'Lat': 63.7256,
#   'Lng': 8.834,
#   'Max Temp': 21.2,
#   'Humidity': 93,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'NO',
#   'Date': '2021-02-07 09:32:17'},
#  {'City': 'Glendive',
#   'Lat': 47.1053,
#   'Lng': -104.7125,
#   'Max Temp': -9.4,
#   'Humidity': 70,
#   'Cloudiness': 90,
#   'Wind Speed': 16.11,
#   'Country': 'US',
#   'Date': '2021-02-07 09:35:34'},
#  {'City': 'Rawson',
#   'Lat': -43.3002,
#   'Lng': -65.1023,
#   'Max Temp': 57.16,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 11.81,
#   'Country': 'AR',
#   'Date': '2021-02-07 09:31:45'},
#  {'City': 'Kavieng',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 83.59,
#   'Humidity': 75,
#   'Cloudiness': 50,
#   'Wind Speed': 8.52,
#   'Country': 'PG',
#   'Date': '2021-02-07 09:31:56'},
#  {'City': 'Brownsville',
#   'Lat': 25.9018,
#   'Lng': -97.4975,
#   'Max Temp': 55.4,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Date': '2021-02-07 09:35:34'},
#  {'City': 'Casa Nova',
#   'Lat': -9.4167,
#   'Lng': -41.1333,
#   'Max Temp': 77,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'BR',
#   'Date': '2021-02-07 09:35:34'},
#  {'City': 'Yulara',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 96.8,
#   'Humidity': 15,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Country': 'AU',
#   'Date': '2021-02-07 09:32:27'},
#  {'City': 'Marzuq',
#   'Lat': 14.4,
#   'Lng': 46.4667,
#   'Max Temp': 78.22,
#   'Humidity': 22,
#   'Cloudiness': 50,
#   'Wind Speed': 8.46,
#   'Country': 'YE',
#   'Date': '2021-02-07 09:35:35'},
#  {'City': 'Cabatuan',
#   'Lat': 10.8794,
#   'Lng': 122.486,
#   'Max Temp': 77.45,
#   'Humidity': 86,
#   'Cloudiness': 45,
#   'Wind Speed': 12.86,
#   'Country': 'PH',
#   'Date': '2021-02-07 09:35:35'},
#  {'City': 'Klyuchi',
#   'Lat': 52.2667,
#   'Lng': 79.1667,
#   'Max Temp': 27.09,
#   'Humidity': 93,
#   'Cloudiness': 34,
#   'Wind Speed': 18.61,
#   'Country': 'RU',
#   'Date': '2021-02-07 09:35:35'},
#  {'City': 'Guerrero Negro',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 56.44,
#   'Humidity': 71,
#   'Cloudiness': 1,
#   'Wind Speed': 2.57,
#   'Country': 'MX',
#   'Date': '2021-02-07 09:32:42'},
#  {'City': 'Desbiens',
#   'Lat': 48.4178,
#   'Lng': -71.9495,
#   'Max Temp': 14,
#   'Humidity': 72,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Country': 'CA',
#   'Date': '2021-02-07 09:35:35'},
#  {'City': 'Westport',
#   'Lat': 41.1415,
#   'Lng': -73.3579,
#   'Max Temp': 33.01,
#   'Humidity': 69,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Date': '2021-02-07 09:35:36'},
#  {'City': 'Kousseri',
#   'Lat': 12.0769,
#   'Lng': 15.0306,
#   'Max Temp': 80.6,
#   'Humidity': 12,
#   'Cloudiness': 31,
#   'Wind Speed': 11.5,
#   'Country': 'CM',
#   'Date': '2021-02-07 09:35:36'},
#  {'City': 'Tyup',
#   'Lat': 42.7276,
#   'Lng': 78.3648,
#   'Max Temp': 36.66,
#   'Humidity': 79,
#   'Cloudiness': 93,
#   'Wind Speed': 3.47,
#   'Country': 'KG',
#   'Date': '2021-02-07 09:35:36'},
#  {'City': 'Tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': -26.77,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 6.6,
#   'Country': 'RU',
#   'Date': '2021-02-07 09:31:56'},
#  {'City': 'Eydhafushi',
#   'Lat': 5.1033,
#   'Lng': 73.0708,
#   'Max Temp': 81.63,
#   'Humidity': 75,
#   'Cloudiness': 19,
#   'Wind Speed': 12.75,
#   'Country': 'MV',
#   'Date': '2021-02-07 09:35:36'},
#  {'City': 'Emerald',
#   'Lat': -23.5333,
#   'Lng': 148.1667,
#   'Max Temp': 84.99,
#   'Humidity': 89,
#   'Cloudiness': 96,
#   'Wind Speed': 6.91,
#   'Country': 'AU',
#   'Date': '2021-02-07 09:35:36'},
#  {'City': 'Mana',
#   'Lat': 5.6592,
#   'Lng': -53.7767,
#   'Max Temp': 76.08,
#   'Humidity': 89,
#   'Cloudiness': 99,
#   'Wind Speed': 10.69,
#   'Country': 'GF',
#   'Date': '2021-02-07 09:35:36'},
#  {'City': 'Vytegra',
#   'Lat': 61.0064,
#   'Lng': 36.4481,
#   'Max Temp': -0.38,
#   'Humidity': 88,
#   'Cloudiness': 17,
#   'Wind Speed': 8.14,
#   'Country': 'RU',
#   'Date': '2021-02-07 09:35:37'},
#  {'City': 'Airai',
# ...
#   'Lat': -23.7,
#   'Lng': 133.8833,
#   'Max Temp': 89.6,
#   'Humidity': 18,
#   'Cloudiness': 22,
#   'Wind Speed': 14.97,
#   'Country': 'AU'},
#  {'City': 'Longyearbyen',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 19.4,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Country': 'SJ'},
#  {'City': 'Fengzhen',
#   'Lat': 40.4394,
#   'Lng': 113.1536,
#   'Max Temp': 24.1,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 3.91,
#   'Country': 'CN'},
#  {'City': 'Saint-Louis',
#   'Lat': 16.3333,
#   'Lng': -15,
#   'Max Temp': 62.6,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Country': 'SN'},
#  {'City': 'Balod',
#   'Lat': 20.73,
#   'Lng': 81.2047,
#   'Max Temp': 83.71,
#   'Humidity': 15,
#   'Cloudiness': 2,
#   'Wind Speed': 7.58,
#   'Country': 'IN'},
#  {'City': 'Chuy',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 65.48,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 2.06,
#   'Country': 'UY'},
#  {'City': 'La Montanita',
#   'Lat': 1.4766,
#   'Lng': -75.4398,
#   'Max Temp': 72.97,
#   'Humidity': 90,
#   'Cloudiness': 99,
#   'Wind Speed': 1.23,
#   'Country': 'CO'},
#  {'City': 'Uddevalla',
#   'Lat': 58.3478,
#   'Lng': 11.9424,
#   'Max Temp': 23,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 11.5,
#   'Country': 'SE'},
#  {'City': 'Kudahuvadhoo',
#   'Lat': 2.6708,
#   'Lng': 72.8944,
#   'Max Temp': 82,
#   'Humidity': 75,
#   'Cloudiness': 65,
#   'Wind Speed': 15.82,
#   'Country': 'MV'},
#  {'City': 'Verkhnyaya Inta',
#   'Lat': 65.9811,
#   'Lng': 60.3094,
#   'Max Temp': -15.41,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 17.22,
#   'Country': 'RU'},
#  {'City': 'Tungor',
#   'Lat': 53.3808,
#   'Lng': 142.9564,
#   'Max Temp': 7.12,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 20.24,
#   'Country': 'RU'},
#  {'City': 'Hamina',
#   'Lat': 60.5697,
#   'Lng': 27.1979,
#   'Max Temp': 19,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 10.36,
#   'Country': 'FI'},
#  {'City': 'Batemans Bay',
#   'Lat': -35.7167,
#   'Lng': 150.1833,
#   'Max Temp': 68,
#   'Humidity': 79,
#   'Cloudiness': 62,
#   'Wind Speed': 4,
#   'Country': 'AU'},
#  {'City': 'Corrente',
#   'Lat': -3.7367,
#   'Lng': -43.3394,
#   'Max Temp': 74.1,
#   'Humidity': 93,
#   'Cloudiness': 28,
#   'Wind Speed': 1.86,
#   'Country': 'BR'},
#  {'City': 'Ostrovnoy',
#   'Lat': 68.0531,
#   'Lng': 39.5131,
#   'Max Temp': 8.08,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 12.93,
#   'Country': 'RU'},
#  {'City': 'Thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': -34.6,
#   'Humidity': 67,
#   'Cloudiness': 20,
#   'Wind Speed': 12.66,
#   'Country': 'CA'},
#  {'City': 'Turka',
#   'Lat': 49.1541,
#   'Lng': 23.0297,
#   'Max Temp': 28,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 8.01,
#   'Country': 'UA'},
#  {'City': 'Ifakara',
#   'Lat': -8.1333,
#   'Lng': 36.6833,
#   'Max Temp': 83.55,
#   'Humidity': 69,
#   'Cloudiness': 97,
#   'Wind Speed': 3.02,
#   'Country': 'TZ'},
#  {'City': 'Ampanihy',
#   'Lat': -24.7,
#   'Lng': 44.75,
#   'Max Temp': 94.32,
#   'Humidity': 45,
#   'Cloudiness': 36,
#   'Wind Speed': 1.21,
#   'Country': 'MG'},
#  {'City': 'Los Llanos De Aridane',
#   'Lat': 28.6585,
#   'Lng': -17.9182,
#   'Max Temp': 60.8,
#   'Humidity': 67,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'ES'},
#  {'City': 'Kargil',
#   'Lat': 34.5667,
#   'Lng': 76.1,
#   'Max Temp': 16.39,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 0.29,
#   'Country': 'IN'},
#  {'City': 'Herat',
#   'Lat': 34.5,
#   'Lng': 62,
#   'Max Temp': 69.8,
#   'Humidity': 18,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Country': 'AF'},
#  {'City': 'Matale',
#   'Lat': 7.4721,
#   'Lng': 80.6234,
#   'Max Temp': 82.49,
#   'Humidity': 62,
#   'Cloudiness': 92,
#   'Wind Speed': 6.76,
#   'Country': 'LK'},
#  {'City': 'Comodoro Rivadavia',
#   'Lat': -45.8667,
#   'Lng': -67.5,
#   'Max Temp': 55.4,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 4.14,
#   'Country': 'AR'},
#  {'City': 'Fort Nelson',
#   'Lat': 58.8053,
#   'Lng': -122.7002,
#   'Max Temp': -27.4,
#   'Humidity': 68,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Country': 'CA'},
#  {'City': 'Harwich',
#   'Lat': 51.9419,
#   'Lng': 1.2844,
#   'Max Temp': 32,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 24,
#   'Country': 'GB'},
#  {'City': 'Arlit',
#   'Lat': 18.7369,
#   'Lng': 7.3853,
#   'Max Temp': 81.75,
#   'Humidity': 12,
#   'Cloudiness': 66,
#   'Wind Speed': 10.25,
#   'Country': 'NE'},
#  {'City': 'Ortigueira',
#   'Lat': -24.2083,
#   'Lng': -50.9494,
#   'Max Temp': 59.05,
#   'Humidity': 96,
#   'Cloudiness': 28,
#   'Wind Speed': 2.51,
#   'Country': 'BR'},
#  {'City': 'Bulgan',
#   'Lat': 48.8125,
#   'Lng': 103.5347,
#   'Max Temp': 11.14,
#   'Humidity': 89,
#   'Cloudiness': 4,
#   'Wind Speed': 2.64,
#   'Country': 'MN'},
#  {'City': 'Udachnyy',
#   'Lat': 66.4167,
#   'Lng': 112.4,
#   'Max Temp': -23.12,
#   'Humidity': 84,
#   'Cloudiness': 98,
#   'Wind Speed': 8.55,
#   'Country': 'RU'},
#  {'City': 'Pavino',
#   'Lat': 59.1139,
#   'Lng': 46.1414,
#   'Max Temp': -9.98,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 10.94,
#   'Country': 'RU'},
#  {'City': 'Farah',
#   'Lat': 32.5,
#   'Lng': 62.5,
#   'Max Temp': 69.89,
#   'Humidity': 18,
#   'Cloudiness': 0,
#   'Wind Speed': 1.63,
#   'Country': 'AF'},
#  {'City': 'Uzhur',
#   'Lat': 55.3036,
#   'Lng': 89.8339,
#   'Max Temp': 20.7,
#   'Humidity': 96,
#   'Cloudiness': 37,
#   'Wind Speed': 6.46,
#   'Country': 'RU'},
#  {'City': 'Tupik',
#   'Lat': 54.4253,
#   'Lng': 119.9327,
#   'Max Temp': -14.91,
#   'Humidity': 84,
#   'Cloudiness': 20,
#   'Wind Speed': 1.99,
#   'Country': 'RU'},
#  {'City': 'Kihurio',
#   'Lat': -4.4667,
#   'Lng': 38.0667,
#   'Max Temp': 85.62,
#   'Humidity': 55,
#   'Cloudiness': 60,
#   'Wind Speed': 8.12,
#   'Country': 'TZ'},
#  {'City': 'Newport',
#   'Lat': 51.5877,
#   'Lng': -2.9984,
#   'Max Temp': 39,
#   'Humidity': 82,
#   'Cloudiness': 93,
#   'Wind Speed': 23.31,
#   'Country': 'GB'},
#  {'City': 'Coolum Beach',
#   'Lat': -26.5333,
#   'Lng': 153.1,
#   'Max Temp': 79,
#   'Humidity': 94,
#   'Cloudiness': 99,
#   'Wind Speed': 5.93,
#   'Country': 'AU'},
#  {'City': 'Burgeo',
#   'Lat': 47.6167,
#   'Lng': -57.6152,
#   'Max Temp': 29.7,
#   'Humidity': 86,
#   'Cloudiness': 82,
#   'Wind Speed': 38.9,
#   'Country': 'CA'},
#  {'City': 'Sao Joao Da Barra',
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 69.8,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'BR'},
#  {'City': 'Miquelon',
#   'Lat': 47.0975,
#   'Lng': -56.3814,
#   'Max Temp': 33.19,
#   'Humidity': 84,
#   'Cloudiness': 99,
#   'Wind Speed': 44.98,
#   'Country': 'PM'},
#  {'City': 'Port Lincoln',
#   'Lat': -34.7333,
#   'Lng': 135.8667,
#   'Max Temp': 62.04,
#   'Humidity': 74,
#   'Cloudiness': 4,
#   'Wind Speed': 14.47,
#   'Country': 'AU'},
#  {'City': 'Krasnoselkup',
#   'Lat': 65.7,
#   'Lng': 82.4667,
#   'Max Temp': -3.32,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 17.36,
#   'Country': 'RU'},
#  {'City': 'Tindivanam',
#   'Lat': 12.25,
#   'Lng': 79.65,
#   'Max Temp': 86,
#   'Humidity': 36,
#   'Cloudiness': 12,
#   'Wind Speed': 16.17,
#   'Country': 'IN'},
#  {'City': 'Ndele',
#   'Lat': 8.4109,
#   'Lng': 20.6473,
#   'Max Temp': 86.77,
#   'Humidity': 13,
#   'Cloudiness': 9,
#   'Wind Speed': 9.13,
#   'Country': 'CF'},
#  {'City': 'Cesky Dub',
#   'Lat': 50.6605,
#   'Lng': 14.9962,
#   'Max Temp': 25,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 3.62,
#   'Country': 'CZ'},
#  {'City': 'Ngaoundere',
#   'Lat': 7.3167,
#   'Lng': 13.5833,
#   'Max Temp': 85.78,
#   'Humidity': 14,
#   'Cloudiness': 99,
#   'Wind Speed': 8.57,
#   'Country': 'CM'},
#  {'City': 'La Ronge',
#   'Lat': 55.1001,
#   'Lng': -105.2842,
#   'Max Temp': -38.2,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'CA'},
#  {'City': 'Chililabombwe',
#   'Lat': -12.3648,
#   'Lng': 27.8229,
#   'Max Temp': 72.75,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 9.6,
#   'Country': 'ZM'},
#  {'City': 'Adeje',
#   'Lat': 28.1227,
#   'Lng': -16.726,
#   'Max Temp': 64,
#   'Humidity': 63,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Country': 'ES'},
#  {'City': 'Wolgast',
#   'Lat': 54.05,
#   'Lng': 13.7667,
#   'Max Temp': 23,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 14.97,
#   'Country': 'DE'},
#  {'City': 'Mirpur Khas',
#   'Lat': 25.5251,
#   'Lng': 69.0159,
#   'Max Temp': 86.4,
#   'Humidity': 12,
#   'Cloudiness': 0,
#   'Wind Speed': 5.28,
#   'Country': 'PK'},
#  {'City': 'Tigil',
#   'Lat': 57.8,
#   'Lng': 158.6667,
#   'Max Temp': 31.33,
#   'Humidity': 93,
#   'Cloudiness': 79,
#   'Wind Speed': 25.46,
#   'Country': 'RU'},
#  {'City': 'Rio Gallegos',
#   'Lat': -51.6226,
#   'Lng': -69.2181,
#   'Max Temp': 49.3,
#   'Humidity': 60,
#   'Cloudiness': 6,
#   'Wind Speed': 5.91,
#   'Country': 'AR'},
#  {'City': 'Kenai',
#   'Lat': 60.5544,
#   'Lng': -151.2583,
#   'Max Temp': 12,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 9.22,
#   'Country': 'US'},
#  {'City': 'Alekseyevsk',
#   'Lat': 57.8406,
#   'Lng': 108.3492,
#   'Max Temp': 17.47,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 13.85,
#   'Country': 'RU'},
#  {'City': 'Portland',
#   'Lat': 45.5234,
#   'Lng': -122.6762,
#   'Max Temp': 44.6,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Country': 'US'},
#  {'City': 'Kununurra',
#   'Lat': -15.7667,
#   'Lng': 128.7333,
#   'Max Temp': 86,
#   'Humidity': 84,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'AU'},
#  {'City': 'Camapua',
#   'Lat': -19.5314,
#   'Lng': -54.0439,
#   'Max Temp': 64.62,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 3.65,
#   'Country': 'BR'},
#  {'City': 'Beauceville',
#   'Lat': 46.2179,
#   'Lng': -70.7787,
#   'Max Temp': 6.8,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Country': 'CA'},
#  {'City': 'Ola',
#   'Lat': 59.5833,
#   'Lng': 151.2833,
#   'Max Temp': 13.44,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 23.49,
#   'Country': 'RU'},
#  {'City': 'Chilca',
#   'Lat': -12.5211,
#   'Lng': -76.7372,
#   'Max Temp': 73,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'PE'},
#  {'City': 'Teguldet',
#   'Lat': 57.3064,
#   'Lng': 88.1667,
#   'Max Temp': 35.38,
#   'Humidity': 86,
#   'Cloudiness': 21,
#   'Wind Speed': 9.62,
#   'Country': 'RU'},
#  {'City': 'Pampa',
#   'Lat': 35.5362,
#   'Lng': -100.9599,
#   'Max Temp': 28.4,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 12.66,
#   'Country': 'US'},
#  {'City': 'Ilulissat',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 28.4,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 27.63,
#   'Country': 'GL'},
#  {'City': 'Torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 32,
#   'Humidity': 69,
#   'Cloudiness': 90,
#   'Wind Speed': 31.07,
#   'Country': 'CA'},
#  {'City': 'Gobabis',
#   'Lat': -22.45,
#   'Lng': 18.9667,
#   'Max Temp': 84.18,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 16.87,
#   'Country': 'NA'},
#  {'City': 'Khasan',
#   'Lat': 42.4308,
#   'Lng': 130.6434,
#   'Max Temp': 15.48,
#   'Humidity': 87,
#   'Cloudiness': 9,
#   'Wind Speed': 8.08,
#   'Country': 'RU'},
#  {'City': 'Kotido',
#   'Lat': 2.9806,
#   'Lng': 34.1331,
#   'Max Temp': 88.16,
#   'Humidity': 14,
#   'Cloudiness': 6,
#   'Wind Speed': 13.78,
#   'Country': 'UG'},
#  {'City': 'Souillac',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 87.8,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 14.97,
#   'Country': 'MU'},
#  {'City': 'Linhares',
#   'Lat': -19.3911,
#   'Lng': -40.0722,
#   'Max Temp': 74.28,
#   'Humidity': 92,
#   'Cloudiness': 99,
#   'Wind Speed': 1.5,
#   'Country': 'BR'},
#  {'City': 'Krasne',
#   'Lat': 49.9145,
#   'Lng': 24.6134,
#   'Max Temp': 17.6,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 15.66,
#   'Country': 'UA'},
#  {'City': 'Cafarnaum',
#   'Lat': -11.6936,
#   'Lng': -41.4683,
#   'Max Temp': 70.95,
#   'Humidity': 84,
#   'Cloudiness': 95,
#   'Wind Speed': 1.36,
#   'Country': 'BR'},
#  {'City': 'Nipawin',
#   'Lat': 53.3668,
#   'Lng': -104.0009,
#   'Max Temp': -27.4,
#   'Humidity': 68,
#   'Cloudiness': 1,
#   'Wind Speed': 10.36,
#   'Country': 'CA'},
#  {'City': 'Atar',
#   'Lat': 20.5169,
#   'Lng': -13.0499,
#   'Max Temp': 59,
#   'Humidity': 23,
#   'Cloudiness': 0,
#   'Wind Speed': 17.27,
#   'Country': 'MR'},
#  {'City': 'Uni',
#   'Lat': 57.7535,
#   'Lng': 51.4923,
#   'Max Temp': -3.96,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 12.3,
#   'Country': 'RU'},
#  {'City': 'Mitu',
#   'Lat': 1.1983,
#   'Lng': -70.1733,
#   'Max Temp': 71.13,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.14,
#   'Country': 'CO'},
#  {'City': 'Mordovo',
#   'Lat': 52.0834,
#   'Lng': 40.77,
#   'Max Temp': 0.28,
#   'Humidity': 90,
#   'Cloudiness': 23,
#   'Wind Speed': 12.8,
#   'Country': 'RU'},
#  {'City': 'Pacific Grove',
#   'Lat': 36.6177,
#   'Lng': -121.9166,
#   'Max Temp': 44.6,
#   'Humidity': 81,
#   'Cloudiness': 20,
#   'Wind Speed': 5.48,
#   'Country': 'US'},
#  {'City': 'Sakiai',
#   'Lat': 54.9547,
#   'Lng': 23.0358,
#   'Max Temp': 3.2,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'LT'},
#  {'City': 'Rumuruti',
#   'Lat': 0.267,
#   'Lng': 36.5389,
#   'Max Temp': 74.01,
#   'Humidity': 44,
#   'Cloudiness': 94,
#   'Wind Speed': 4.47,
#   'Country': 'KE'},
#  {'City': 'Vila Velha',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp': 71.6,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Country': 'BR'},
#  {'City': 'Poso',
#   'Lat': -1.3959,
#   'Lng': 120.7524,
#   'Max Temp': 81.66,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 0.58,
#   'Country': 'ID'},
#  {'City': 'Basoko',
#   'Lat': 1.2391,
#   'Lng': 23.616,
#   'Max Temp': 90.97,
#   'Humidity': 25,
#   'Cloudiness': 41,
#   'Wind Speed': 3.96,
#   'Country': 'CD'},
#  {'City': 'Castle Rock',
#   'Lat': 39.3722,
#   'Lng': -104.8561,
#   'Max Temp': 34,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 1.99,
#   'Country': 'US'},
#  {'City': 'Touros',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 75.2,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'BR'},
#  {'City': 'Tateyama',
#   'Lat': 34.9833,
#   'Lng': 139.8667,
#   'Max Temp': 55,
#   'Humidity': 82,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Country': 'JP'},
#  {'City': 'Ust-Maya',
#   'Lat': 60.4167,
#   'Lng': 134.5333,
#   'Max Temp': -30.8,
#   'Humidity': 82,
#   'Cloudiness': 11,
#   'Wind Speed': 2.75,
#   'Country': 'RU'},
#  {'City': 'Promyshlennaya',
#   'Lat': 54.9159,
#   'Lng': 85.6385,
#   'Max Temp': 33.8,
#   'Humidity': 86,
#   'Cloudiness': 40,
#   'Wind Speed': 15.66,
#   'Country': 'RU'},
#  {'City': 'Yar-Sale',
#   'Lat': 66.8333,
#   'Lng': 70.8333,
#   'Max Temp': -13.41,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 24.99,
#   'Country': 'RU'},
#  {'City': 'Binghamton',
#   'Lat': 42.0987,
#   'Lng': -75.918,
#   'Max Temp': 19.4,
#   'Humidity': 45,
#   'Cloudiness': 1,
#   'Wind Speed': 6.91,
#   'Country': 'US'},
#  {'City': 'Christchurch',
#   'Lat': -43.5333,
#   'Lng': 172.6333,
#   'Max Temp': 62.01,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 14.97,
#   'Country': 'NZ'},
#  {'City': 'Meulaboh',
#   'Lat': 4.1363,
#   'Lng': 96.1285,
#   'Max Temp': 85.03,
#   'Humidity': 67,
#   'Cloudiness': 85,
#   'Wind Speed': 6.02,
#   'Country': 'ID'},
#  {'City': 'Araouane',
#   'Lat': 18.9048,
#   'Lng': -3.5265,
#   'Max Temp': 67.75,
#   'Humidity': 26,
#   'Cloudiness': 93,
#   'Wind Speed': 19.35,
#   'Country': 'ML'},
#  {'City': 'Walvis Bay',
#   'Lat': -22.9575,
#   'Lng': 14.5053,
#   'Max Temp': 68,
#   'Humidity': 68,
#   'Cloudiness': 31,
#   'Wind Speed': 9.22,
#   'Country': 'NA'},
#  {'City': 'Solsona',
#   'Lat': 41.994,
#   'Lng': 1.5171,
#   'Max Temp': 41,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'ES'},
#  {'City': 'Broken Hill',
#   'Lat': -31.95,
#   'Lng': 141.4333,
#   'Max Temp': 78.8,
#   'Humidity': 31,
#   'Cloudiness': 0,
#   'Wind Speed': 14.97,
#   'Country': 'AU'},
#  {'City': 'Ranavav',
#   'Lat': 21.6842,
#   'Lng': 69.7408,
#   'Max Temp': 84.2,
#   'Humidity': 21,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Country': 'IN'},
#  {'City': 'Tezu',
#   'Lat': 27.9167,
#   'Lng': 96.1667,
#   'Max Temp': 77.79,
#   'Humidity': 20,
#   'Cloudiness': 0,
#   'Wind Speed': 3.67,
#   'Country': 'IN'},
#  {'City': 'Yarada',
#   'Lat': 17.65,
#   'Lng': 83.2667,
#   'Max Temp': 82.4,
#   'Humidity': 39,
#   'Cloudiness': 83,
#   'Wind Speed': 12.66,
#   'Country': 'IN'},
#  {'City': 'Miraflores',
#   'Lat': 19.2167,
#   'Lng': -98.8083,
#   'Max Temp': 55.4,
#   'Humidity': 47,
#   'Cloudiness': 1,
#   'Wind Speed': 2.48,
#   'Country': 'MX'},
#  {'City': 'Nabire',
#   'Lat': -3.3667,
#   'Lng': 135.4833,
#   'Max Temp': 79.41,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 1.88,
#   'Country': 'ID'},
#  ...]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Vaini -21.2000 -175.2000     78.80        94          75
# 1      Nishihara  26.1842  127.7558     66.20        52          20
# 2        Rikitea -23.1203 -134.9692     77.11        74          49
# 3        Ushuaia -54.8000  -68.3000     44.60        76          40
# 4       Hermanus -34.4187   19.2345     69.01        81          99
# 5      Mount Isa -20.7333  139.5000     82.40        74         100
# 6       Antalaha -14.9003   50.2788     84.94        63          47
# 7        Honiara  -9.4333  159.9500     78.78        82         100
# 8  West Wendover  40.7391 -114.0733     48.20        20           1
# 9         Yantal  56.8471  105.2542     22.15        95         100
#
#    Wind Speed Country                 Date
# 0       10.36      TO  2021-02-07 09:31:32
# 1        8.05      JP  2021-02-07 09:35:01
# 2       11.30      PF  2021-02-07 09:31:23
# 3        9.22      AR  2021-02-07 09:30:10
# 4        3.00      ZA  2021-02-07 09:31:28
# 5        9.22      AU  2021-02-07 09:32:03
# 6        7.40      MG  2021-02-07 09:35:01
# 7        6.44      SB  2021-02-07 09:34:15
# 8       12.66      US  2021-02-07 09:32:09
# 9       10.11      RU  2021-02-07 09:35:02

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="WeatherPy_Database.csv")
